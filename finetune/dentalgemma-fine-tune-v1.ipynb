# %% [markdown]
# # 🦷 Fine-tune MedGemma for Dental Diagnostics
#
# This notebook fine-tunes **[MedGemma 1.5 4B IT](https://huggingface.co/google/medgemma-1.5-4b-it)** on dental X-ray analysis using the **[DentalGemma](https://huggingface.co/datasets/naazimsnh02/dentalgemma-vqa)** datasets — a novel domain adaptation since MedGemma was **not** trained on dental data.
#
# **Fine-tuning approach:**
# - **LoRA with full bfloat16 precision** for optimal training quality
# - **TRL SFTTrainer** for supervised fine-tuning
# - Two-stage training: multimodal VQA (image + text) → text-only clinical instruct data
#
# **Datasets:**
# - [`naazimsnh02/dentalgemma-vqa`](https://huggingface.co/datasets/naazimsnh02/dentalgemma-vqa) — 1,654 dental X-ray VQA pairs
# - [`naazimsnh02/dentalgemma-instruct`](https://huggingface.co/datasets/naazimsnh02/dentalgemma-instruct) — 2,494 clinical dental cases
#
# **Built for the [MedGemma Impact Challenge](https://kaggle.com/competitions/med-gemma-impact-challenge).**

# %% [markdown]
# ## Setup
#
# **Requirements:** A GPU with bfloat16 support and ≥40 GB VRAM (e.g., A100).
#
# **Google Colab:**
# 1. Click **▾ (Additional connection options)** → **Change runtime type**
# 2. Select **A100 GPU** under Hardware accelerator

# %% [markdown]
# ### Get access to MedGemma
#
# 1. Create a [Hugging Face account](https://huggingface.co/join) if you don't have one
# 2. Accept usage conditions at [google/medgemma-1.5-4b-it](https://huggingface.co/google/medgemma-1.5-4b-it)

# %% [markdown]
# ### Configure your HF token
#
# Generate a Hugging Face **write** access token at [settings/tokens](https://huggingface.co/settings/tokens).
#
# **Google Colab:** Add your token to the 🔑 Secrets tab as `HF_TOKEN`.

# %%
import os
import sys

if "google.colab" in sys.modules and not os.environ.get("VERTEX_PRODUCT"):
    from google.colab import userdata
    os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")
else:
    if os.environ.get("VERTEX_PRODUCT") == "COLAB_ENTERPRISE":
        os.environ["HF_HOME"] = "/content/hf"
    from huggingface_hub import get_token
    if get_token() is None:
        from huggingface_hub import notebook_login
        notebook_login()

# %%
import os
from huggingface_hub import get_token

# 1. Check if the env var is injected
if "HF_TOKEN" in os.environ:
    print("✅ Success! 'HF_TOKEN' environment variable is present.")
    print(f"Token starts with: {os.environ['HF_TOKEN'][:4]}****")
else:
    print("❌ 'HF_TOKEN' environment variable is MISSING.")

# 2. Check what Hugging Face sees
token = get_token()
if token:
    print(f"✅ Hugging Face Login Status: Authenticated (Token found)")
else:
    print("❌ Hugging Face Login Status: Not Logged In")
# Out:
# ✅ Success! 'HF_TOKEN' environment variable is present.
# Token starts with: hf_u****
# ✅ Hugging Face Login Status: Authenticated (Token found)

# %% [markdown]
# ### Install dependencies

# %%
# Uninstall incompatible PyTorch and torchvision versions
# %uv pip uninstall torch torchvision torchaudio
# Out:
# Using Python 3.12.6 environment at: /usr/local
# Uninstalled 3 packages in 2.01s
#  - torch==2.8.0+cu129
#  - torchaudio==2.8.0+cu129
#  - torchvision==0.23.0+cu129
# Note: you may need to restart the kernel to use updated packages.

# %%
# Install compatible PyTorch and torchvision versions
# %uv pip install torch==2.9.0+cu128 torchvision==0.24.0+cu128 --index-url https://download.pytorch.org/whl/cu128
# Out:
# Using Python 3.12.6 environment at: /usr/local
# Resolved 29 packages in 2.74s
# ⠙ Preparing packages... (0/16)
# ⠙ Preparing packages... (0/16)
# nvidia-cufile-cu12 ------------------------------     0 B/1.14 MiB
# ⠙ Preparing packages... (0/16)
# nvidia-cufile-cu12 ------------------------------ 16.00 KiB/1.14 MiB
# ⠙ Preparing packages... (0/16)
# nvidia-cufile-cu12 ------------------------------ 16.00 KiB/1.14 MiB
# torchvision ------------------------------     0 B/7.68 MiB
# ⠙ Preparing packages... (0/16)
# nvidia-cufile-cu12 ------------------------------ 16.00 KiB/1.14 MiB
# torchvision ------------------------------ 8.00 KiB/7.68 MiB
# ⠙ Preparing packages... (0/16)
# nvidia-cufile-cu12 ------------------------------ 16.00 KiB/1.14 MiB
# torchvision ------------------------------ 8.00 KiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/9.77 MiB
# ⠙ Preparing packages... (0/16)
# nvidia-cufile-cu12 ------------------------------ 16.00 KiB/1.14 MiB
# torchvision ------------------------------ 8.00 KiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/9.77 MiB
# ⠙ Preparing packages... (0/16)
# nvidia-cufile-cu12 ------------------------------ 16.00 KiB/1.14 MiB
# torchvision ------------------------------ 8.00 KiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/9.77 MiB
# triton     ------------------------------     0 B/162.57 MiB
# ⠙ Preparing packages... (0/16)
# nvidia-cufile-cu12 ------------------------------ 16.00 KiB/1.14 MiB
# torchvision ------------------------------ 8.00 KiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/9.77 MiB
# triton     ------------------------------ 8.00 KiB/162.57 MiB
# ⠙ Preparing packages... (0/16)
# nvidia-cufile-cu12 ------------------------------ 16.00 KiB/1.14 MiB
# torchvision ------------------------------ 8.00 KiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/9.77 MiB
# triton     ------------------------------ 16.00 KiB/162.57 MiB
# ⠙ Preparing packages... (0/16)
# nvidia-cufile-cu12 ------------------------------ 16.00 KiB/1.14 MiB
# torchvision ------------------------------ 8.00 KiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/9.77 MiB
# triton     ------------------------------ 24.00 KiB/162.57 MiB
# ⠙ Preparing packages... (0/16)
# nvidia-cufile-cu12 ------------------------------ 16.00 KiB/1.14 MiB
# torchvision ------------------------------ 8.00 KiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/9.77 MiB
# triton     ------------------------------ 32.00 KiB/162.57 MiB
# ⠙ Preparing packages... (0/16)
# nvidia-cufile-cu12 ------------------------------ 16.00 KiB/1.14 MiB
# torchvision ------------------------------ 8.00 KiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/9.77 MiB
# triton     ------------------------------ 40.00 KiB/162.57 MiB
# ⠙ Preparing packages... (0/16)
# nvidia-cufile-cu12 ------------------------------ 16.00 KiB/1.14 MiB
# torchvision ------------------------------ 8.00 KiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/9.77 MiB
# triton     ------------------------------ 48.00 KiB/162.57 MiB
# ⠙ Preparing packages... (0/16)
# nvidia-cufile-cu12 ------------------------------ 16.00 KiB/1.14 MiB
# torchvision ------------------------------ 8.00 KiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/9.77 MiB
# triton     ------------------------------ 56.00 KiB/162.57 MiB
# ⠙ Preparing packages... (0/16)
# nvidia-cufile-cu12 ------------------------------ 16.00 KiB/1.14 MiB
# torchvision ------------------------------ 8.00 KiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/9.77 MiB
# triton     ------------------------------ 64.00 KiB/162.57 MiB
# ⠙ Preparing packages... (0/16)
# nvidia-cufile-cu12 ------------------------------ 16.00 KiB/1.14 MiB
# torchvision ------------------------------ 8.00 KiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/9.77 MiB
# triton     ------------------------------ 65.54 KiB/162.57 MiB
# ⠙ Preparing packages... (0/16)
# nvidia-cufile-cu12 ------------------------------ 16.00 KiB/1.14 MiB
# torchvision ------------------------------ 8.00 KiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/9.77 MiB
# triton     ------------------------------ 73.54 KiB/162.57 MiB
# ⠙ Preparing packages... (0/16)
# nvidia-cufile-cu12 ------------------------------ 192.00 KiB/1.14 MiB
# torchvision ------------------------------ 16.00 KiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/9.77 MiB
# triton     ------------------------------ 414.17 KiB/162.57 MiB
# nvidia-cublas-cu12 ------------------------------ 16.00 KiB/566.81 MiB
# ⠙ Preparing packages... (0/16)
# nvidia-nvtx-cu12 ------------------------------ 16.00 KiB/87.85 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 16.00 KiB/932.39 KiB
# nvidia-cufile-cu12 ------------------------------ 493.17 KiB/1.14 MiB
# torchvision ------------------------------ 1.96 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 16.00 KiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 16.00 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 16.00 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 16.00 KiB/118.88 MiB
# triton     ------------------------------ 414.17 KiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 16.00 KiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 16.00 KiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 16.00 KiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 16.00 KiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 16.00 KiB/566.81 MiB
# ⠙ Preparing packages... (0/16)
# nvidia-nvtx-cu12 ------------------------------ 16.00 KiB/87.85 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 16.00 KiB/932.39 KiB
# nvidia-cufile-cu12 ------------------------------ 493.17 KiB/1.14 MiB
# torchvision ------------------------------ 2.02 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 16.00 KiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 16.00 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 16.00 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 16.00 KiB/118.88 MiB
# triton     ------------------------------ 872.97 KiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 16.00 KiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 16.00 KiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 32.00 KiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 285.64 KiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 48.00 KiB/566.81 MiB
# ⠹ Preparing packages... (0/16)
# nvidia-nvtx-cu12 ------------------------------ 16.00 KiB/87.85 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 32.00 KiB/932.39 KiB
# nvidia-cufile-cu12 ------------------------------ 555.67 KiB/1.14 MiB
# torchvision ------------------------------ 2.02 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 48.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 301.60 KiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 16.00 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 285.60 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 16.00 KiB/118.88 MiB
# triton     ------------------------------ 2.09 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 16.00 KiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 16.00 KiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 32.00 KiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 285.64 KiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 48.00 KiB/566.81 MiB
# ⠹ Preparing packages... (0/16)
# nvidia-nvtx-cu12 ------------------------------ 32.00 KiB/87.85 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 32.00 KiB/932.39 KiB
# nvidia-cufile-cu12 ------------------------------ 681.87 KiB/1.14 MiB
# torchvision ------------------------------ 2.12 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 64.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 301.60 KiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 16.00 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 285.60 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 16.00 KiB/118.88 MiB
# triton     ------------------------------ 3.05 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 16.00 KiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 32.00 KiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 508.10 KiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 377.31 KiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 732.12 KiB/566.81 MiB
# ⠹ Preparing packages... (0/16)
# nvidia-nvtx-cu12 ------------------------------ 48.00 KiB/87.85 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 224.00 KiB/932.39 KiB
# nvidia-cufile-cu12 ------------------------------ 762.17 KiB/1.14 MiB
# torchvision ------------------------------ 2.19 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 80.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 301.60 KiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 32.00 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 285.60 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 16.00 KiB/118.88 MiB
# triton     ------------------------------ 3.05 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 413.60 KiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 32.00 KiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 508.10 KiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 508.14 KiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 1.88 MiB/566.81 MiB
# ⠹ Preparing packages... (0/16)
# nvidia-nvtx-cu12 ------------------------------ 48.00 KiB/87.85 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 224.00 KiB/932.39 KiB
# nvidia-cufile-cu12 ------------------------------ 1.09 MiB/1.14 MiB
# torchvision ------------------------------ 2.20 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 80.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 301.60 KiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 48.00 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 285.60 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 16.00 KiB/118.88 MiB
# triton     ------------------------------ 4.07 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 508.10 KiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 32.00 KiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 508.10 KiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 684.14 KiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 2.03 MiB/566.81 MiB
# ⠸ Preparing packages... (0/16)
# nvidia-nvtx-cu12 ------------------------------ 48.00 KiB/87.85 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 224.00 KiB/932.39 KiB
# nvidia-cufile-cu12 ------------------------------ 1.09 MiB/1.14 MiB
# torchvision ------------------------------ 2.20 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 80.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 301.60 KiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 64.00 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 508.10 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 16.00 KiB/118.88 MiB
# triton     ------------------------------ 4.75 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 716.10 KiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 636.12 KiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 906.60 KiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 684.14 KiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 2.03 MiB/566.81 MiB
# ⠸ Preparing packages... (0/16)
# nvidia-nvtx-cu12 ------------------------------ 48.00 KiB/87.85 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 240.00 KiB/932.39 KiB
# nvidia-cufile-cu12 ------------------------------ 1.13 MiB/1.14 MiB
# torchvision ------------------------------ 2.20 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 96.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 540.10 KiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 64.00 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 588.10 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 16.00 KiB/118.88 MiB
# triton     ------------------------------ 5.78 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 716.10 KiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 762.62 KiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 1017.10 KiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 762.64 KiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 2.03 MiB/566.81 MiB
# ⠸ Preparing packages... (0/16)
# nvidia-nvtx-cu12 ------------------------------ 48.00 KiB/87.85 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 240.00 KiB/932.39 KiB
# nvidia-cufile-cu12 ------------------------------ 1.14 MiB/1.14 MiB
# torchvision ------------------------------ 2.20 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 96.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 540.10 KiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 128.00 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 970.60 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 32.00 KiB/118.88 MiB
# triton     ------------------------------ 6.00 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 861.12 KiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.24 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.43 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 906.64 KiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 2.03 MiB/566.81 MiB
# ⠸ Preparing packages... (0/16)
# nvidia-nvtx-cu12 ------------------------------ 64.00 KiB/87.85 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 268.40 KiB/932.39 KiB
# torchvision ------------------------------ 2.21 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 112.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 616.50 KiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 144.00 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1017.10 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 32.00 KiB/118.88 MiB
# triton     ------------------------------ 7.13 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 909.12 KiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.27 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.49 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 1017.14 KiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 2.46 MiB/566.81 MiB
# ⠼ Preparing packages... (1/16)
# nvidia-nvtx-cu12 ------------------------------ 64.00 KiB/87.85 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 268.40 KiB/932.39 KiB
# torchvision ------------------------------ 2.22 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 128.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 616.50 KiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 445.62 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1017.10 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 32.00 KiB/118.88 MiB
# triton     ------------------------------ 7.13 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 909.12 KiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.27 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.49 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 1017.14 KiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 2.46 MiB/566.81 MiB
# ⠼ Preparing packages... (1/16)
# nvidia-nvtx-cu12 ------------------------------ 64.00 KiB/87.85 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 284.40 KiB/932.39 KiB
# torchvision ------------------------------ 2.22 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 128.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 616.50 KiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 445.62 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1017.10 KiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 32.00 KiB/118.88 MiB
# triton     ------------------------------ 8.13 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 1017.10 KiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.38 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.66 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 1017.14 KiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 2.46 MiB/566.81 MiB
# ⠼ Preparing packages... (1/16)
# nvidia-nvtx-cu12 ------------------------------ 64.00 KiB/87.85 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 300.40 KiB/932.39 KiB
# torchvision ------------------------------ 2.22 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 144.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 762.60 KiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 874.62 KiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.07 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 32.00 KiB/118.88 MiB
# triton     ------------------------------ 8.65 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 1.18 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.55 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.80 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 1.13 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 2.46 MiB/566.81 MiB
# ⠼ Preparing packages... (1/16)
# nvidia-nvtx-cu12 ------------------------------ 64.00 KiB/87.85 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 316.40 KiB/932.39 KiB
# torchvision ------------------------------ 2.22 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 144.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 827.20 KiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 1.33 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.07 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 48.00 KiB/118.88 MiB
# triton     ------------------------------ 9.09 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 1.24 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.65 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.90 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 1.23 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 2.46 MiB/566.81 MiB
# ⠴ Preparing packages... (1/16)
# nvidia-nvtx-cu12 ------------------------------ 80.00 KiB/87.85 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 332.40 KiB/932.39 KiB
# torchvision ------------------------------ 2.23 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 144.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1017.10 KiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 1.34 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.24 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 48.00 KiB/118.88 MiB
# triton     ------------------------------ 10.04 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 1.24 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.74 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.99 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 1.46 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 2.70 MiB/566.81 MiB
# ⠴ Preparing packages... (1/16)
# nvidia-nvtx-cu12 ------------------------------ 80.00 KiB/87.85 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 348.40 KiB/932.39 KiB
# torchvision ------------------------------ 2.23 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 144.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.23 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 1.47 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.24 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 48.00 KiB/118.88 MiB
# triton     ------------------------------ 10.47 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 1.46 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.96 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.00 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 1.69 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 2.99 MiB/566.81 MiB
# ⠴ Preparing packages... (1/16)
# nvidia-nvtx-cu12 ------------------------------ 80.00 KiB/87.85 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 348.40 KiB/932.39 KiB
# torchvision ------------------------------ 2.23 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 144.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.23 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 1.65 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.34 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 48.00 KiB/118.88 MiB
# triton     ------------------------------ 12.08 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 1.77 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.00 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.22 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 1.69 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 3.01 MiB/566.81 MiB
# ⠴ Preparing packages... (1/16)
# nvidia-nvtx-cu12 ------------------------------ 87.85 KiB/87.85 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 364.40 KiB/932.39 KiB
# torchvision ------------------------------ 2.23 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 160.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.35 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 1.89 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.66 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 48.00 KiB/118.88 MiB
# triton     ------------------------------ 13.09 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 1.94 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.14 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.37 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 1.90 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 3.12 MiB/566.81 MiB
# ⠴ Preparing packages... (1/16)
# nvidia-nvtx-cu12 ------------------------------ 87.85 KiB/87.85 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 364.40 KiB/932.39 KiB
# torchvision ------------------------------ 2.23 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 160.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.49 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 1.99 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.00 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 48.00 KiB/118.88 MiB
# triton     ------------------------------ 14.08 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 1.99 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.25 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.50 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 1.92 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 3.24 MiB/566.81 MiB
# ⠦ Preparing packages... (1/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 380.40 KiB/932.39 KiB
# torchvision ------------------------------ 2.24 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 176.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.54 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 1.99 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.00 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 48.00 KiB/118.88 MiB
# triton     ------------------------------ 15.06 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 2.20 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.47 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.64 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 1.99 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 3.43 MiB/566.81 MiB
# ⠦ Preparing packages... (1/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 396.40 KiB/932.39 KiB
# torchvision ------------------------------ 2.24 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 176.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.54 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 1.99 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.00 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 64.00 KiB/118.88 MiB
# triton     ------------------------------ 15.06 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 2.42 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.47 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.64 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 1.99 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 3.43 MiB/566.81 MiB
# ⠦ Preparing packages... (1/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 522.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.26 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 192.00 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.55 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 2.00 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.00 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 80.00 KiB/118.88 MiB
# triton     ------------------------------ 16.32 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 2.48 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.01 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.74 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 1.99 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 3.43 MiB/566.81 MiB
# ⠦ Preparing packages... (1/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 538.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.27 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 395.93 KiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.74 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 2.17 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.22 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 96.00 KiB/118.88 MiB
# triton     ------------------------------ 18.03 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 2.74 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.01 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.90 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 2.00 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 3.43 MiB/566.81 MiB
# ⠧ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 538.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.27 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.73 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.93 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 2.40 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.42 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 96.00 KiB/118.88 MiB
# triton     ------------------------------ 18.03 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 2.74 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.18 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.99 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 2.16 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 3.49 MiB/566.81 MiB
# ⠧ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 538.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.27 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.97 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.99 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 2.59 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.50 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 112.00 KiB/118.88 MiB
# triton     ------------------------------ 19.14 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 2.89 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.38 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.20 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 2.45 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 3.75 MiB/566.81 MiB
# ⠧ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 538.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.27 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.20 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.99 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 2.74 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.87 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 112.00 KiB/118.88 MiB
# triton     ------------------------------ 20.05 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 2.99 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.49 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.24 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 2.50 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 3.75 MiB/566.81 MiB
# ⠧ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 538.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.28 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.45 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.17 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 2.86 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.96 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 128.00 KiB/118.88 MiB
# triton     ------------------------------ 21.07 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 3.41 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.99 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.44 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 2.71 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 3.97 MiB/566.81 MiB
# ⠇ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 538.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.28 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.72 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.74 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 2.99 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.23 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 128.00 KiB/118.88 MiB
# triton     ------------------------------ 21.07 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 3.74 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.00 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.74 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 3.63 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 3.97 MiB/566.81 MiB
# ⠇ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 538.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.28 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.72 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.74 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 2.99 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.27 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 128.00 KiB/118.88 MiB
# triton     ------------------------------ 22.12 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 3.74 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.00 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.74 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 3.96 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 3.97 MiB/566.81 MiB
# ⠇ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 586.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.28 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.18 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.74 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 3.18 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.00 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 128.00 KiB/118.88 MiB
# triton     ------------------------------ 23.08 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 3.74 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.23 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.94 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 3.96 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 4.25 MiB/566.81 MiB
# ⠇ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 586.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.28 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.45 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.02 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 3.43 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.25 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 144.00 KiB/118.88 MiB
# triton     ------------------------------ 23.08 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 3.93 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.39 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.00 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 4.07 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 4.90 MiB/566.81 MiB
# ⠋ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 586.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.29 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.45 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.02 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 3.43 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.25 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 2.06 MiB/118.88 MiB
# triton     ------------------------------ 24.12 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 3.93 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.39 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.00 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 4.07 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 4.90 MiB/566.81 MiB
# ⠋ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 586.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.29 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.54 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.88 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 3.66 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.25 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 2.06 MiB/118.88 MiB
# triton     ------------------------------ 24.72 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 4.48 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.68 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.00 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 4.07 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 5.49 MiB/566.81 MiB
# ⠋ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 602.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.30 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.73 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.00 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 3.66 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.47 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 2.65 MiB/118.88 MiB
# triton     ------------------------------ 25.15 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 4.48 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.95 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.22 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 4.07 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 5.94 MiB/566.81 MiB
# ⠋ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 602.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.30 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.73 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.00 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 3.66 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.47 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 2.65 MiB/118.88 MiB
# triton     ------------------------------ 26.10 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 4.48 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 5.32 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.22 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 4.07 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 5.94 MiB/566.81 MiB
# ⠋ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 602.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.30 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.18 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.42 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 3.91 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.98 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 2.98 MiB/118.88 MiB
# triton     ------------------------------ 26.10 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 4.99 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 5.48 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.73 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 4.47 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 6.20 MiB/566.81 MiB
# ⠙ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 602.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.30 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.24 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.42 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 3.91 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.98 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 2.98 MiB/118.88 MiB
# triton     ------------------------------ 27.12 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 4.99 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 5.48 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.73 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 4.47 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 6.20 MiB/566.81 MiB
# ⠙ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 602.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.30 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.47 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 5.24 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 4.17 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.21 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 3.71 MiB/118.88 MiB
# triton     ------------------------------ 27.14 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 5.23 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 5.72 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.95 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 4.70 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 8.00 MiB/566.81 MiB
# ⠙ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 602.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.30 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.47 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 5.24 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 4.17 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.21 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 3.75 MiB/118.88 MiB
# triton     ------------------------------ 28.07 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 5.60 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 5.72 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.95 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 4.70 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 8.00 MiB/566.81 MiB
# ⠙ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 602.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.30 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.92 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 5.24 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 4.42 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.46 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 3.75 MiB/118.88 MiB
# triton     ------------------------------ 28.57 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 6.02 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 5.94 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.20 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 4.70 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 9.44 MiB/566.81 MiB
# ⠹ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 618.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.30 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.92 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 5.24 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 4.42 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.46 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 4.76 MiB/118.88 MiB
# triton     ------------------------------ 29.04 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 6.02 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 5.94 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.20 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 4.70 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 9.44 MiB/566.81 MiB
# ⠹ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 618.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.31 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 5.22 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 5.94 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 4.67 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.71 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 5.18 MiB/118.88 MiB
# triton     ------------------------------ 29.17 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 6.25 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 6.00 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.44 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 4.99 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 10.48 MiB/566.81 MiB
# ⠹ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 618.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.31 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 5.22 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 5.94 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 4.67 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.71 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 5.18 MiB/118.88 MiB
# triton     ------------------------------ 30.12 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 6.25 MiB/184.17 MiB
# nvidia-cusolver-cu12 ------------------------------ 6.00 MiB/255.11 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.44 MiB/274.86 MiB
# nvidia-nccl-cu12 ------------------------------ 4.99 MiB/307.42 MiB
# nvidia-cublas-cu12 ------------------------------ 10.52 MiB/566.81 MiB
# ⠹ Preparing packages... (2/16)
# nvidia-cuda-runtime-cu12 ------------------------------ 618.90 KiB/932.39 KiB
# torchvision ------------------------------ 2.31 MiB/7.68 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 5.47 MiB/9.77 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 5.94 MiB/37.44 MiB
# nvidia-curand-cu12 ------------------------------ 4.67 MiB/60.67 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.99 MiB/83.96 MiB
# nvidia-nvshmem-cu12 ------------------------------ 5.93 MiB/118.88 MiB
# triton     ------------------------------ 30.12 MiB/162.57 MiB
# nvidia-cufft-cu12 ------------------------------ 6.44 MiB/184.17 MiB
# ...
# ⠸ Preparing packages... (13/16)
# nvidia-cusparse-cu12 ------------------------------ 261.32 MiB/274.86 MiB
# nvidia-cublas-cu12 ------------------------------ 525.49 MiB/566.81 MiB
# ⠸ Preparing packages... (13/16)
# nvidia-cusparse-cu12 ------------------------------ 263.49 MiB/274.86 MiB
# nvidia-cublas-cu12 ------------------------------ 525.49 MiB/566.81 MiB
# ⠸ Preparing packages... (13/16)
# nvidia-cusparse-cu12 ------------------------------ 266.47 MiB/274.86 MiB
# nvidia-cublas-cu12 ------------------------------ 528.19 MiB/566.81 MiB
# ⠸ Preparing packages... (13/16)
# nvidia-cusparse-cu12 ------------------------------ 266.98 MiB/274.86 MiB
# nvidia-cublas-cu12 ------------------------------ 530.09 MiB/566.81 MiB
# ⠼ Preparing packages... (13/16)
# nvidia-cusparse-cu12 ------------------------------ 268.51 MiB/274.86 MiB
# nvidia-cublas-cu12 ------------------------------ 530.39 MiB/566.81 MiB
# ⠼ Preparing packages... (13/16)
# nvidia-cusparse-cu12 ------------------------------ 270.44 MiB/274.86 MiB
# nvidia-cublas-cu12 ------------------------------ 531.91 MiB/566.81 MiB
# ⠼ Preparing packages... (13/16)
# nvidia-cusparse-cu12 ------------------------------ 270.73 MiB/274.86 MiB
# nvidia-cublas-cu12 ------------------------------ 533.82 MiB/566.81 MiB
# ⠼ Preparing packages... (13/16)
# nvidia-cusparse-cu12 ------------------------------ 272.53 MiB/274.86 MiB
# nvidia-cublas-cu12 ------------------------------ 535.80 MiB/566.81 MiB
# ⠴ Preparing packages... (13/16)
# nvidia-cusparse-cu12 ------------------------------ 274.47 MiB/274.86 MiB
# nvidia-cublas-cu12 ------------------------------ 537.75 MiB/566.81 MiB
# ⠴ Preparing packages... (13/16)
# nvidia-cublas-cu12 ------------------------------ 537.96 MiB/566.81 MiB
# ⠴ Preparing packages... (13/16)
# nvidia-cublas-cu12 ------------------------------ 538.00 MiB/566.81 MiB
# ⠴ Preparing packages... (13/16)
# nvidia-cublas-cu12 ------------------------------ 540.37 MiB/566.81 MiB
# ⠴ Preparing packages... (13/16)
# nvidia-cublas-cu12 ------------------------------ 543.75 MiB/566.81 MiB
# ⠦ Preparing packages... (14/16)
# nvidia-cublas-cu12 ------------------------------ 545.77 MiB/566.81 MiB
# ⠦ Preparing packages... (14/16)
# nvidia-cublas-cu12 ------------------------------ 548.51 MiB/566.81 MiB
# ⠦ Preparing packages... (14/16)
# nvidia-cublas-cu12 ------------------------------ 552.17 MiB/566.81 MiB
# ⠦ Preparing packages... (14/16)
# nvidia-cublas-cu12 ------------------------------ 554.65 MiB/566.81 MiB
# ⠧ Preparing packages... (14/16)
# nvidia-cublas-cu12 ------------------------------ 560.00 MiB/566.81 MiB
# ⠧ Preparing packages... (14/16)
# nvidia-cublas-cu12 ------------------------------ 564.02 MiB/566.81 MiB
# ⠧ Preparing packages... (14/16)
# ⠧ Preparing packages... (14/16)
# ⠧ Preparing packages... (14/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠼ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠴ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠦ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠙ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠹ Preparing packages... (15/16)
# ⠸ Preparing packages... (15/16)
# Prepared 16 packages in 56.35s
# Uninstalled 14 packages in 165ms
# Installed 16 packages in 1.21s
#  - nvidia-cublas-cu12==12.9.1.4
#  + nvidia-cublas-cu12==12.8.4.1
#  - nvidia-cuda-cupti-cu12==12.9.79
#  + nvidia-cuda-cupti-cu12==12.8.90
#  - nvidia-cuda-nvrtc-cu12==12.9.86
#  + nvidia-cuda-nvrtc-cu12==12.8.93
#  - nvidia-cuda-runtime-cu12==12.9.79
#  + nvidia-cuda-runtime-cu12==12.8.90
#  - nvidia-cufft-cu12==11.4.1.4
#  + nvidia-cufft-cu12==11.3.3.83
#  - nvidia-cufile-cu12==1.14.1.1
#  + nvidia-cufile-cu12==1.13.1.3
#  - nvidia-curand-cu12==10.3.10.19
#  + nvidia-curand-cu12==10.3.9.90
#  - nvidia-cusolver-cu12==11.7.5.82
#  + nvidia-cusolver-cu12==11.7.3.90
#  - nvidia-cusparse-cu12==12.5.10.65
#  + nvidia-cusparse-cu12==12.5.8.93
#  - nvidia-nccl-cu12==2.27.3
#  + nvidia-nccl-cu12==2.27.5
#  - nvidia-nvjitlink-cu12==12.9.86
#  + nvidia-nvjitlink-cu12==12.8.93
#  - nvidia-nvshmem-cu12==3.3.24
#  + nvidia-nvshmem-cu12==3.3.20
#  - nvidia-nvtx-cu12==12.9.79
#  + nvidia-nvtx-cu12==12.8.90
#  + torch==2.9.0+cu128
#  + torchvision==0.24.0+cu128
#  - triton==3.4.0
#  + triton==3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Install other dependencies
# %uv pip install accelerate bitsandbytes datasets evaluate peft tensorboard transformers trl
# Out:
# Using Python 3.12.6 environment at: /usr/local
# Resolved 86 packages in 671ms
# ⠙ Preparing packages... (0/16)
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------     0 B/116.86 KiB
# ⠙ Preparing packages... (0/16)
# dill       ------------------------------ 14.89 KiB/116.86 KiB
# ⠙ Preparing packages... (0/16)
# typer      ------------------------------     0 B/55.48 KiB
# dill       ------------------------------ 14.89 KiB/116.86 KiB
# ⠙ Preparing packages... (0/16)
# typer      ------------------------------ 14.89 KiB/55.48 KiB
# dill       ------------------------------ 14.89 KiB/116.86 KiB
# ⠙ Preparing packages... (0/16)
# annotated-doc ------------------------------     0 B/5.18 KiB
# typer      ------------------------------ 14.89 KiB/55.48 KiB
# dill       ------------------------------ 14.89 KiB/116.86 KiB
# ⠙ Preparing packages... (0/16)
# annotated-doc ------------------------------ 5.18 KiB/5.18 KiB
# typer      ------------------------------ 14.89 KiB/55.48 KiB
# dill       ------------------------------ 14.89 KiB/116.86 KiB
# ⠙ Preparing packages... (0/16)
# annotated-doc ------------------------------ 5.18 KiB/5.18 KiB
# typer      ------------------------------ 14.89 KiB/55.48 KiB
# dill       ------------------------------ 14.89 KiB/116.86 KiB
# huggingface-hub ------------------------------     0 B/540.36 KiB
# ⠙ Preparing packages... (0/16)
# annotated-doc ------------------------------ 5.18 KiB/5.18 KiB
# typer      ------------------------------ 14.89 KiB/55.48 KiB
# dill       ------------------------------ 14.89 KiB/116.86 KiB
# huggingface-hub ------------------------------ 14.88 KiB/540.36 KiB
# ⠙ Preparing packages... (0/16)
# annotated-doc ------------------------------ 5.18 KiB/5.18 KiB
# typer      ------------------------------ 14.89 KiB/55.48 KiB
# dill       ------------------------------ 30.89 KiB/116.86 KiB
# huggingface-hub ------------------------------ 14.88 KiB/540.36 KiB
# ⠙ Preparing packages... (0/16)
# annotated-doc ------------------------------ 5.18 KiB/5.18 KiB
# typer      ------------------------------ 14.89 KiB/55.48 KiB
# dill       ------------------------------ 30.89 KiB/116.86 KiB
# huggingface-hub ------------------------------ 30.88 KiB/540.36 KiB
# ⠙ Preparing packages... (0/16)
# annotated-doc ------------------------------ 5.18 KiB/5.18 KiB
# typer      ------------------------------ 14.89 KiB/55.48 KiB
# dill       ------------------------------ 30.89 KiB/116.86 KiB
# huggingface-hub ------------------------------ 30.88 KiB/540.36 KiB
# ⠙ Preparing packages... (0/16)
# annotated-doc ------------------------------ 5.18 KiB/5.18 KiB
# typer      ------------------------------ 14.89 KiB/55.48 KiB
# dill       ------------------------------ 30.89 KiB/116.86 KiB
# huggingface-hub ------------------------------ 30.88 KiB/540.36 KiB
# transformers ------------------------------     0 B/9.80 MiB
# ⠙ Preparing packages... (0/16)
# annotated-doc ------------------------------ 5.18 KiB/5.18 KiB
# typer      ------------------------------ 14.89 KiB/55.48 KiB
# dill       ------------------------------ 30.89 KiB/116.86 KiB
# huggingface-hub ------------------------------ 30.88 KiB/540.36 KiB
# transformers ------------------------------ 16.00 KiB/9.80 MiB
# ⠙ Preparing packages... (0/16)
# annotated-doc ------------------------------ 5.18 KiB/5.18 KiB
# typer      ------------------------------ 14.89 KiB/55.48 KiB
# dill       ------------------------------ 30.89 KiB/116.86 KiB
# huggingface-hub ------------------------------ 30.88 KiB/540.36 KiB
# hf-xet     ------------------------------     0 B/3.17 MiB
# transformers ------------------------------ 16.00 KiB/9.80 MiB
# ⠙ Preparing packages... (0/16)
# annotated-doc ------------------------------ 5.18 KiB/5.18 KiB
# typer      ------------------------------ 14.89 KiB/55.48 KiB
# dill       ------------------------------ 30.89 KiB/116.86 KiB
# huggingface-hub ------------------------------ 30.88 KiB/540.36 KiB
# hf-xet     ------------------------------ 16.00 KiB/3.17 MiB
# transformers ------------------------------ 16.00 KiB/9.80 MiB
# ⠙ Preparing packages... (0/16)
# annotated-doc ------------------------------ 5.18 KiB/5.18 KiB
# typer      ------------------------------ 14.89 KiB/55.48 KiB
# dill       ------------------------------ 30.89 KiB/116.86 KiB
# trl        ------------------------------     0 B/527.86 KiB
# huggingface-hub ------------------------------ 30.88 KiB/540.36 KiB
# hf-xet     ------------------------------ 16.00 KiB/3.17 MiB
# transformers ------------------------------ 16.00 KiB/9.80 MiB
# ⠙ Preparing packages... (0/16)
# typer-slim ------------------------------ 3.32 KiB/3.32 KiB
# annotated-doc ------------------------------ 5.18 KiB/5.18 KiB
# typer      ------------------------------ 14.89 KiB/55.48 KiB
# evaluate   ------------------------------     0 B/82.10 KiB
# dill       ------------------------------ 46.89 KiB/116.86 KiB
# multiprocess ------------------------------ 16.00 KiB/146.76 KiB
# xxhash     ------------------------------     0 B/189.34 KiB
# datasets   ------------------------------     0 B/503.12 KiB
# trl        ------------------------------ 14.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 30.88 KiB/540.36 KiB
# peft       ------------------------------     0 B/543.91 KiB
# tokenizers ------------------------------     0 B/3.12 MiB
# hf-xet     ------------------------------ 16.00 KiB/3.17 MiB
# transformers ------------------------------ 16.00 KiB/9.80 MiB
# pyarrow    ------------------------------ 16.00 KiB/45.35 MiB
# ⠙ Preparing packages... (0/16)
# typer-slim ------------------------------ 3.32 KiB/3.32 KiB
# annotated-doc ------------------------------ 5.18 KiB/5.18 KiB
# typer      ------------------------------ 14.89 KiB/55.48 KiB
# evaluate   ------------------------------ 16.00 KiB/82.10 KiB
# dill       ------------------------------ 46.89 KiB/116.86 KiB
# multiprocess ------------------------------ 16.00 KiB/146.76 KiB
# xxhash     ------------------------------ 16.00 KiB/189.34 KiB
# datasets   ------------------------------ 64.00 KiB/503.12 KiB
# trl        ------------------------------ 14.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 46.88 KiB/540.36 KiB
# peft       ------------------------------ 14.92 KiB/543.91 KiB
# tokenizers ------------------------------ 16.00 KiB/3.12 MiB
# hf-xet     ------------------------------ 526.87 KiB/3.17 MiB
# transformers ------------------------------ 32.00 KiB/9.80 MiB
# pyarrow    ------------------------------ 124.27 KiB/45.35 MiB
# ⠙ Preparing packages... (0/16)
# typer-slim ------------------------------ 3.32 KiB/3.32 KiB
# typer      ------------------------------ 14.89 KiB/55.48 KiB
# evaluate   ------------------------------ 16.00 KiB/82.10 KiB
# dill       ------------------------------ 46.89 KiB/116.86 KiB
# multiprocess ------------------------------ 16.00 KiB/146.76 KiB
# xxhash     ------------------------------ 189.34 KiB/189.34 KiB
# datasets   ------------------------------ 80.00 KiB/503.12 KiB
# trl        ------------------------------ 14.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 46.88 KiB/540.36 KiB
# peft       ------------------------------ 14.92 KiB/543.91 KiB
# tokenizers ------------------------------ 16.00 KiB/3.12 MiB
# hf-xet     ------------------------------ 605.14 KiB/3.17 MiB
# transformers ------------------------------ 32.00 KiB/9.80 MiB
# pyarrow    ------------------------------ 124.27 KiB/45.35 MiB
# ⠙ Preparing packages... (0/16)
# typer      ------------------------------ 14.89 KiB/55.48 KiB
# evaluate   ------------------------------ 16.00 KiB/82.10 KiB
# dill       ------------------------------ 62.60 KiB/116.86 KiB
# multiprocess ------------------------------ 16.00 KiB/146.76 KiB
# xxhash     ------------------------------ 189.34 KiB/189.34 KiB
# datasets   ------------------------------ 96.00 KiB/503.12 KiB
# trl        ------------------------------ 30.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 46.88 KiB/540.36 KiB
# peft       ------------------------------ 14.92 KiB/543.91 KiB
# tokenizers ------------------------------ 16.00 KiB/3.12 MiB
# hf-xet     ------------------------------ 686.87 KiB/3.17 MiB
# transformers ------------------------------ 60.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 177.13 KiB/45.35 MiB
# ⠙ Preparing packages... (0/16)
# typer      ------------------------------ 14.89 KiB/55.48 KiB
# evaluate   ------------------------------ 32.00 KiB/82.10 KiB
# dill       ------------------------------ 78.60 KiB/116.86 KiB
# multiprocess ------------------------------ 32.00 KiB/146.76 KiB
# xxhash     ------------------------------ 189.34 KiB/189.34 KiB
# datasets   ------------------------------ 112.00 KiB/503.12 KiB
# trl        ------------------------------ 30.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 62.88 KiB/540.36 KiB
# peft       ------------------------------ 30.92 KiB/543.91 KiB
# tokenizers ------------------------------ 16.00 KiB/3.12 MiB
# hf-xet     ------------------------------ 720.31 KiB/3.17 MiB
# transformers ------------------------------ 76.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 541.72 KiB/45.35 MiB
# ⠙ Preparing packages... (0/16)
# typer      ------------------------------ 46.89 KiB/55.48 KiB
# evaluate   ------------------------------ 48.00 KiB/82.10 KiB
# dill       ------------------------------ 78.60 KiB/116.86 KiB
# multiprocess ------------------------------ 54.13 KiB/146.76 KiB
# datasets   ------------------------------ 144.00 KiB/503.12 KiB
# trl        ------------------------------ 30.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 76.24 KiB/540.36 KiB
# peft       ------------------------------ 62.92 KiB/543.91 KiB
# tokenizers ------------------------------ 32.00 KiB/3.12 MiB
# hf-xet     ------------------------------ 1.09 MiB/3.17 MiB
# transformers ------------------------------ 100.54 KiB/9.80 MiB
# pyarrow    ------------------------------ 717.72 KiB/45.35 MiB
# ⠙ Preparing packages... (0/16)
# typer      ------------------------------ 46.89 KiB/55.48 KiB
# evaluate   ------------------------------ 48.00 KiB/82.10 KiB
# dill       ------------------------------ 78.60 KiB/116.86 KiB
# multiprocess ------------------------------ 54.13 KiB/146.76 KiB
# datasets   ------------------------------ 144.00 KiB/503.12 KiB
# trl        ------------------------------ 30.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 76.24 KiB/540.36 KiB
# peft       ------------------------------ 62.92 KiB/543.91 KiB
# tokenizers ------------------------------ 32.00 KiB/3.12 MiB
# hf-xet     ------------------------------ 1.09 MiB/3.17 MiB
# transformers ------------------------------ 100.54 KiB/9.80 MiB
# pyarrow    ------------------------------ 733.72 KiB/45.35 MiB
# ⠹ Preparing packages... (2/16)
# evaluate   ------------------------------ 48.00 KiB/82.10 KiB
# dill       ------------------------------ 78.60 KiB/116.86 KiB
# multiprocess ------------------------------ 64.00 KiB/146.76 KiB
# datasets   ------------------------------ 192.00 KiB/503.12 KiB
# trl        ------------------------------ 46.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 92.24 KiB/540.36 KiB
# peft       ------------------------------ 62.92 KiB/543.91 KiB
# tokenizers ------------------------------ 32.00 KiB/3.12 MiB
# hf-xet     ------------------------------ 1.16 MiB/3.17 MiB
# transformers ------------------------------ 124.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 1005.72 KiB/45.35 MiB
# ⠹ Preparing packages... (2/16)
# evaluate   ------------------------------ 64.00 KiB/82.10 KiB
# dill       ------------------------------ 94.89 KiB/116.86 KiB
# multiprocess ------------------------------ 80.00 KiB/146.76 KiB
# datasets   ------------------------------ 224.00 KiB/503.12 KiB
# trl        ------------------------------ 62.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 220.24 KiB/540.36 KiB
# peft       ------------------------------ 94.92 KiB/543.91 KiB
# tokenizers ------------------------------ 32.00 KiB/3.12 MiB
# hf-xet     ------------------------------ 1.31 MiB/3.17 MiB
# transformers ------------------------------ 140.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 1.24 MiB/45.35 MiB
# ⠹ Preparing packages... (2/16)
# evaluate   ------------------------------ 80.00 KiB/82.10 KiB
# dill       ------------------------------ 94.89 KiB/116.86 KiB
# multiprocess ------------------------------ 144.00 KiB/146.76 KiB
# datasets   ------------------------------ 256.00 KiB/503.12 KiB
# trl        ------------------------------ 94.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 252.24 KiB/540.36 KiB
# peft       ------------------------------ 126.92 KiB/543.91 KiB
# tokenizers ------------------------------ 909.44 KiB/3.12 MiB
# hf-xet     ------------------------------ 1.54 MiB/3.17 MiB
# transformers ------------------------------ 207.73 KiB/9.80 MiB
# pyarrow    ------------------------------ 1.70 MiB/45.35 MiB
# ⠹ Preparing packages... (2/16)
# evaluate   ------------------------------ 80.00 KiB/82.10 KiB
# dill       ------------------------------ 110.89 KiB/116.86 KiB
# multiprocess ------------------------------ 144.00 KiB/146.76 KiB
# datasets   ------------------------------ 256.00 KiB/503.12 KiB
# trl        ------------------------------ 94.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 268.24 KiB/540.36 KiB
# peft       ------------------------------ 126.92 KiB/543.91 KiB
# tokenizers ------------------------------ 2.00 MiB/3.12 MiB
# hf-xet     ------------------------------ 2.00 MiB/3.17 MiB
# transformers ------------------------------ 239.73 KiB/9.80 MiB
# pyarrow    ------------------------------ 1.87 MiB/45.35 MiB
# ⠹ Preparing packages... (2/16)
# dill       ------------------------------ 110.89 KiB/116.86 KiB
# multiprocess ------------------------------ 144.00 KiB/146.76 KiB
# datasets   ------------------------------ 256.00 KiB/503.12 KiB
# trl        ------------------------------ 94.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 268.24 KiB/540.36 KiB
# peft       ------------------------------ 126.92 KiB/543.91 KiB
# tokenizers ------------------------------ 2.36 MiB/3.12 MiB
# hf-xet     ------------------------------ 2.31 MiB/3.17 MiB
# transformers ------------------------------ 316.57 KiB/9.80 MiB
# pyarrow    ------------------------------ 1.88 MiB/45.35 MiB
# ⠹ Preparing packages... (2/16)
# dill       ------------------------------ 110.89 KiB/116.86 KiB
# multiprocess ------------------------------ 144.00 KiB/146.76 KiB
# datasets   ------------------------------ 272.00 KiB/503.12 KiB
# trl        ------------------------------ 94.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 284.24 KiB/540.36 KiB
# peft       ------------------------------ 126.92 KiB/543.91 KiB
# tokenizers ------------------------------ 2.36 MiB/3.12 MiB
# hf-xet     ------------------------------ 2.47 MiB/3.17 MiB
# transformers ------------------------------ 316.57 KiB/9.80 MiB
# pyarrow    ------------------------------ 1.93 MiB/45.35 MiB
# ⠸ Preparing packages... (5/16)
# dill       ------------------------------ 110.89 KiB/116.86 KiB
# multiprocess ------------------------------ 144.00 KiB/146.76 KiB
# datasets   ------------------------------ 288.00 KiB/503.12 KiB
# trl        ------------------------------ 126.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 284.24 KiB/540.36 KiB
# peft       ------------------------------ 142.92 KiB/543.91 KiB
# tokenizers ------------------------------ 3.00 MiB/3.12 MiB
# hf-xet     ------------------------------ 3.00 MiB/3.17 MiB
# transformers ------------------------------ 380.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 2.03 MiB/45.35 MiB
# ⠸ Preparing packages... (5/16)
# dill       ------------------------------ 110.89 KiB/116.86 KiB
# multiprocess ------------------------------ 144.00 KiB/146.76 KiB
# datasets   ------------------------------ 288.00 KiB/503.12 KiB
# trl        ------------------------------ 142.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 284.24 KiB/540.36 KiB
# peft       ------------------------------ 142.92 KiB/543.91 KiB
# hf-xet     ------------------------------ 3.17 MiB/3.17 MiB
# transformers ------------------------------ 444.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 2.12 MiB/45.35 MiB
# ⠸ Preparing packages... (5/16)
# dill       ------------------------------ 116.86 KiB/116.86 KiB
# multiprocess ------------------------------ 144.00 KiB/146.76 KiB
# datasets   ------------------------------ 304.00 KiB/503.12 KiB
# trl        ------------------------------ 142.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 316.24 KiB/540.36 KiB
# peft       ------------------------------ 142.92 KiB/543.91 KiB
# hf-xet     ------------------------------ 3.17 MiB/3.17 MiB
# transformers ------------------------------ 508.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 2.33 MiB/45.35 MiB
# ⠸ Preparing packages... (5/16)
# multiprocess ------------------------------ 144.00 KiB/146.76 KiB
# datasets   ------------------------------ 304.00 KiB/503.12 KiB
# trl        ------------------------------ 142.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 350.85 KiB/540.36 KiB
# peft       ------------------------------ 142.92 KiB/543.91 KiB
# hf-xet     ------------------------------ 3.17 MiB/3.17 MiB
# transformers ------------------------------ 524.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 2.47 MiB/45.35 MiB
# ⠸ Preparing packages... (5/16)
# multiprocess ------------------------------ 144.00 KiB/146.76 KiB
# datasets   ------------------------------ 304.00 KiB/503.12 KiB
# trl        ------------------------------ 158.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 350.85 KiB/540.36 KiB
# peft       ------------------------------ 158.92 KiB/543.91 KiB
# transformers ------------------------------ 540.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 2.47 MiB/45.35 MiB
# ⠸ Preparing packages... (5/16)
# datasets   ------------------------------ 320.00 KiB/503.12 KiB
# trl        ------------------------------ 158.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 350.85 KiB/540.36 KiB
# peft       ------------------------------ 158.92 KiB/543.91 KiB
# transformers ------------------------------ 588.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 2.50 MiB/45.35 MiB
# ⠸ Preparing packages... (5/16)
# datasets   ------------------------------ 320.00 KiB/503.12 KiB
# trl        ------------------------------ 174.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 350.85 KiB/540.36 KiB
# peft       ------------------------------ 158.92 KiB/543.91 KiB
# transformers ------------------------------ 588.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 2.50 MiB/45.35 MiB
# ⠸ Preparing packages... (5/16)
# datasets   ------------------------------ 336.00 KiB/503.12 KiB
# trl        ------------------------------ 270.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 388.31 KiB/540.36 KiB
# peft       ------------------------------ 206.92 KiB/543.91 KiB
# transformers ------------------------------ 697.29 KiB/9.80 MiB
# pyarrow    ------------------------------ 2.76 MiB/45.35 MiB
# ⠼ Preparing packages... (9/16)
# datasets   ------------------------------ 352.00 KiB/503.12 KiB
# trl        ------------------------------ 270.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 388.31 KiB/540.36 KiB
# peft       ------------------------------ 222.82 KiB/543.91 KiB
# transformers ------------------------------ 748.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 4.17 MiB/45.35 MiB
# ⠼ Preparing packages... (9/16)
# datasets   ------------------------------ 352.00 KiB/503.12 KiB
# trl        ------------------------------ 286.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 388.31 KiB/540.36 KiB
# peft       ------------------------------ 238.71 KiB/543.91 KiB
# transformers ------------------------------ 796.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 5.98 MiB/45.35 MiB
# ⠼ Preparing packages... (9/16)
# datasets   ------------------------------ 352.00 KiB/503.12 KiB
# trl        ------------------------------ 286.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 396.24 KiB/540.36 KiB
# peft       ------------------------------ 238.71 KiB/543.91 KiB
# transformers ------------------------------ 812.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 6.72 MiB/45.35 MiB
# ⠼ Preparing packages... (9/16)
# datasets   ------------------------------ 352.00 KiB/503.12 KiB
# trl        ------------------------------ 302.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 402.47 KiB/540.36 KiB
# peft       ------------------------------ 270.71 KiB/543.91 KiB
# transformers ------------------------------ 844.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 8.34 MiB/45.35 MiB
# ⠴ Preparing packages... (9/16)
# datasets   ------------------------------ 352.00 KiB/503.12 KiB
# trl        ------------------------------ 302.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 402.47 KiB/540.36 KiB
# peft       ------------------------------ 286.82 KiB/543.91 KiB
# transformers ------------------------------ 844.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 10.91 MiB/45.35 MiB
# ⠴ Preparing packages... (9/16)
# datasets   ------------------------------ 368.00 KiB/503.12 KiB
# trl        ------------------------------ 318.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 418.47 KiB/540.36 KiB
# peft       ------------------------------ 302.82 KiB/543.91 KiB
# transformers ------------------------------ 876.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 12.73 MiB/45.35 MiB
# ⠴ Preparing packages... (9/16)
# datasets   ------------------------------ 368.00 KiB/503.12 KiB
# trl        ------------------------------ 334.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 418.47 KiB/540.36 KiB
# peft       ------------------------------ 318.82 KiB/543.91 KiB
# transformers ------------------------------ 908.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 14.16 MiB/45.35 MiB
# ⠴ Preparing packages... (9/16)
# datasets   ------------------------------ 368.00 KiB/503.12 KiB
# trl        ------------------------------ 334.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 418.47 KiB/540.36 KiB
# peft       ------------------------------ 318.82 KiB/543.91 KiB
# transformers ------------------------------ 924.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 15.09 MiB/45.35 MiB
# ⠦ Preparing packages... (9/16)
# datasets   ------------------------------ 384.00 KiB/503.12 KiB
# trl        ------------------------------ 350.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 418.47 KiB/540.36 KiB
# peft       ------------------------------ 318.82 KiB/543.91 KiB
# transformers ------------------------------ 924.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 15.20 MiB/45.35 MiB
# ⠦ Preparing packages... (9/16)
# datasets   ------------------------------ 384.00 KiB/503.12 KiB
# trl        ------------------------------ 350.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 434.47 KiB/540.36 KiB
# peft       ------------------------------ 318.82 KiB/543.91 KiB
# transformers ------------------------------ 956.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 17.10 MiB/45.35 MiB
# ⠦ Preparing packages... (9/16)
# datasets   ------------------------------ 392.56 KiB/503.12 KiB
# trl        ------------------------------ 350.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 434.47 KiB/540.36 KiB
# peft       ------------------------------ 334.82 KiB/543.91 KiB
# transformers ------------------------------ 972.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 17.93 MiB/45.35 MiB
# ⠦ Preparing packages... (9/16)
# datasets   ------------------------------ 392.56 KiB/503.12 KiB
# trl        ------------------------------ 350.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 448.56 KiB/540.36 KiB
# peft       ------------------------------ 334.82 KiB/543.91 KiB
# transformers ------------------------------ 972.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 19.42 MiB/45.35 MiB
# ⠧ Preparing packages... (9/16)
# datasets   ------------------------------ 408.56 KiB/503.12 KiB
# trl        ------------------------------ 382.92 KiB/527.86 KiB
# huggingface-hub ------------------------------ 448.56 KiB/540.36 KiB
# peft       ------------------------------ 334.82 KiB/543.91 KiB
# transformers ------------------------------ 992.74 KiB/9.80 MiB
# pyarrow    ------------------------------ 19.64 MiB/45.35 MiB
# ⠧ Preparing packages... (9/16)
# datasets   ------------------------------ 408.56 KiB/503.12 KiB
# trl        ------------------------------ 432.41 KiB/527.86 KiB
# huggingface-hub ------------------------------ 448.56 KiB/540.36 KiB
# peft       ------------------------------ 350.92 KiB/543.91 KiB
# transformers ------------------------------ 992.74 KiB/9.80 MiB
# pyarrow    ------------------------------ 20.59 MiB/45.35 MiB
# ⠧ Preparing packages... (9/16)
# datasets   ------------------------------ 408.56 KiB/503.12 KiB
# trl        ------------------------------ 432.41 KiB/527.86 KiB
# huggingface-hub ------------------------------ 460.24 KiB/540.36 KiB
# peft       ------------------------------ 350.92 KiB/543.91 KiB
# transformers ------------------------------ 992.74 KiB/9.80 MiB
# pyarrow    ------------------------------ 21.59 MiB/45.35 MiB
# ⠧ Preparing packages... (9/16)
# datasets   ------------------------------ 424.56 KiB/503.12 KiB
# trl        ------------------------------ 432.41 KiB/527.86 KiB
# huggingface-hub ------------------------------ 460.24 KiB/540.36 KiB
# peft       ------------------------------ 350.92 KiB/543.91 KiB
# transformers ------------------------------ 1004.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 22.97 MiB/45.35 MiB
# ⠇ Preparing packages... (9/16)
# datasets   ------------------------------ 424.56 KiB/503.12 KiB
# trl        ------------------------------ 432.41 KiB/527.86 KiB
# huggingface-hub ------------------------------ 460.24 KiB/540.36 KiB
# peft       ------------------------------ 350.92 KiB/543.91 KiB
# transformers ------------------------------ 1004.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 23.66 MiB/45.35 MiB
# ⠇ Preparing packages... (9/16)
# datasets   ------------------------------ 481.10 KiB/503.12 KiB
# trl        ------------------------------ 432.41 KiB/527.86 KiB
# huggingface-hub ------------------------------ 464.34 KiB/540.36 KiB
# peft       ------------------------------ 350.92 KiB/543.91 KiB
# transformers ------------------------------ 1004.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 24.86 MiB/45.35 MiB
# ⠇ Preparing packages... (9/16)
# datasets   ------------------------------ 481.10 KiB/503.12 KiB
# trl        ------------------------------ 432.41 KiB/527.86 KiB
# huggingface-hub ------------------------------ 480.34 KiB/540.36 KiB
# peft       ------------------------------ 350.92 KiB/543.91 KiB
# transformers ------------------------------ 1020.90 KiB/9.80 MiB
# pyarrow    ------------------------------ 25.94 MiB/45.35 MiB
# ⠇ Preparing packages... (9/16)
# datasets   ------------------------------ 497.10 KiB/503.12 KiB
# trl        ------------------------------ 432.41 KiB/527.86 KiB
# huggingface-hub ------------------------------ 480.34 KiB/540.36 KiB
# peft       ------------------------------ 350.92 KiB/543.91 KiB
# transformers ------------------------------ 1.01 MiB/9.80 MiB
# pyarrow    ------------------------------ 26.62 MiB/45.35 MiB
# ⠋ Preparing packages... (9/16)
# datasets   ------------------------------ 497.10 KiB/503.12 KiB
# trl        ------------------------------ 448.41 KiB/527.86 KiB
# huggingface-hub ------------------------------ 496.34 KiB/540.36 KiB
# peft       ------------------------------ 350.92 KiB/543.91 KiB
# transformers ------------------------------ 1.01 MiB/9.80 MiB
# pyarrow    ------------------------------ 27.30 MiB/45.35 MiB
# ⠋ Preparing packages... (9/16)
# datasets   ------------------------------ 497.10 KiB/503.12 KiB
# trl        ------------------------------ 472.56 KiB/527.86 KiB
# huggingface-hub ------------------------------ 496.34 KiB/540.36 KiB
# peft       ------------------------------ 366.92 KiB/543.91 KiB
# transformers ------------------------------ 1.01 MiB/9.80 MiB
# pyarrow    ------------------------------ 28.42 MiB/45.35 MiB
# ⠋ Preparing packages... (9/16)
# trl        ------------------------------ 472.56 KiB/527.86 KiB
# huggingface-hub ------------------------------ 496.34 KiB/540.36 KiB
# peft       ------------------------------ 366.92 KiB/543.91 KiB
# transformers ------------------------------ 1.01 MiB/9.80 MiB
# pyarrow    ------------------------------ 29.83 MiB/45.35 MiB
# ⠋ Preparing packages... (9/16)
# trl        ------------------------------ 504.56 KiB/527.86 KiB
# huggingface-hub ------------------------------ 496.34 KiB/540.36 KiB
# peft       ------------------------------ 366.92 KiB/543.91 KiB
# transformers ------------------------------ 1.03 MiB/9.80 MiB
# pyarrow    ------------------------------ 29.86 MiB/45.35 MiB
# ⠋ Preparing packages... (9/16)
# trl        ------------------------------ 504.56 KiB/527.86 KiB
# huggingface-hub ------------------------------ 496.34 KiB/540.36 KiB
# peft       ------------------------------ 366.92 KiB/543.91 KiB
# transformers ------------------------------ 1.03 MiB/9.80 MiB
# pyarrow    ------------------------------ 30.97 MiB/45.35 MiB
# ⠙ Preparing packages... (10/16)
# trl        ------------------------------ 511.77 KiB/527.86 KiB
# huggingface-hub ------------------------------ 519.43 KiB/540.36 KiB
# peft       ------------------------------ 382.92 KiB/543.91 KiB
# transformers ------------------------------ 1.05 MiB/9.80 MiB
# pyarrow    ------------------------------ 32.09 MiB/45.35 MiB
# ⠙ Preparing packages... (10/16)
# trl        ------------------------------ 511.77 KiB/527.86 KiB
# huggingface-hub ------------------------------ 519.43 KiB/540.36 KiB
# peft       ------------------------------ 382.92 KiB/543.91 KiB
# transformers ------------------------------ 1.05 MiB/9.80 MiB
# pyarrow    ------------------------------ 32.09 MiB/45.35 MiB
# ⠙ Preparing packages... (10/16)
# huggingface-hub ------------------------------ 519.43 KiB/540.36 KiB
# peft       ------------------------------ 382.92 KiB/543.91 KiB
# transformers ------------------------------ 1.05 MiB/9.80 MiB
# pyarrow    ------------------------------ 33.97 MiB/45.35 MiB
# ⠙ Preparing packages... (10/16)
# huggingface-hub ------------------------------ 519.43 KiB/540.36 KiB
# peft       ------------------------------ 392.56 KiB/543.91 KiB
# transformers ------------------------------ 1.05 MiB/9.80 MiB
# pyarrow    ------------------------------ 33.98 MiB/45.35 MiB
# ⠙ Preparing packages... (10/16)
# peft       ------------------------------ 392.56 KiB/543.91 KiB
# transformers ------------------------------ 1.07 MiB/9.80 MiB
# pyarrow    ------------------------------ 35.06 MiB/45.35 MiB
# ⠙ Preparing packages... (10/16)
# peft       ------------------------------ 408.56 KiB/543.91 KiB
# transformers ------------------------------ 1.07 MiB/9.80 MiB
# pyarrow    ------------------------------ 35.06 MiB/45.35 MiB
# ⠹ Preparing packages... (11/16)
# peft       ------------------------------ 408.56 KiB/543.91 KiB
# transformers ------------------------------ 1.09 MiB/9.80 MiB
# pyarrow    ------------------------------ 35.64 MiB/45.35 MiB
# ⠹ Preparing packages... (11/16)
# peft       ------------------------------ 408.56 KiB/543.91 KiB
# transformers ------------------------------ 1.09 MiB/9.80 MiB
# pyarrow    ------------------------------ 36.69 MiB/45.35 MiB
# ⠹ Preparing packages... (11/16)
# peft       ------------------------------ 408.56 KiB/543.91 KiB
# transformers ------------------------------ 1.09 MiB/9.80 MiB
# pyarrow    ------------------------------ 37.50 MiB/45.35 MiB
# ⠹ Preparing packages... (11/16)
# peft       ------------------------------ 424.56 KiB/543.91 KiB
# transformers ------------------------------ 1.10 MiB/9.80 MiB
# pyarrow    ------------------------------ 37.65 MiB/45.35 MiB
# ⠸ Preparing packages... (12/16)
# peft       ------------------------------ 424.56 KiB/543.91 KiB
# transformers ------------------------------ 1.12 MiB/9.80 MiB
# pyarrow    ------------------------------ 39.50 MiB/45.35 MiB
# ⠸ Preparing packages... (12/16)
# peft       ------------------------------ 424.56 KiB/543.91 KiB
# transformers ------------------------------ 1.12 MiB/9.80 MiB
# pyarrow    ------------------------------ 40.78 MiB/45.35 MiB
# ⠸ Preparing packages... (12/16)
# peft       ------------------------------ 456.56 KiB/543.91 KiB
# transformers ------------------------------ 1.16 MiB/9.80 MiB
# pyarrow    ------------------------------ 40.78 MiB/45.35 MiB
# ⠸ Preparing packages... (12/16)
# peft       ------------------------------ 471.76 KiB/543.91 KiB
# transformers ------------------------------ 1.17 MiB/9.80 MiB
# pyarrow    ------------------------------ 42.04 MiB/45.35 MiB
# ⠼ Preparing packages... (12/16)
# peft       ------------------------------ 487.76 KiB/543.91 KiB
# transformers ------------------------------ 1.20 MiB/9.80 MiB
# pyarrow    ------------------------------ 43.30 MiB/45.35 MiB
# ⠼ Preparing packages... (12/16)
# transformers ------------------------------ 1.27 MiB/9.80 MiB
# pyarrow    ------------------------------ 43.37 MiB/45.35 MiB
# ⠼ Preparing packages... (12/16)
# transformers ------------------------------ 1.27 MiB/9.80 MiB
# pyarrow    ------------------------------ 43.39 MiB/45.35 MiB
# ⠼ Preparing packages... (12/16)
# transformers ------------------------------ 1.34 MiB/9.80 MiB
# pyarrow    ------------------------------ 43.42 MiB/45.35 MiB
# ⠼ Preparing packages... (12/16)
# transformers ------------------------------ 1.49 MiB/9.80 MiB
# pyarrow    ------------------------------ 43.56 MiB/45.35 MiB
# ⠴ Preparing packages... (13/16)
# transformers ------------------------------ 1.55 MiB/9.80 MiB
# ⠴ Preparing packages... (13/16)
# transformers ------------------------------ 1.84 MiB/9.80 MiB
# ⠴ Preparing packages... (13/16)
# transformers ------------------------------ 2.15 MiB/9.80 MiB
# ⠴ Preparing packages... (13/16)
# transformers ------------------------------ 2.50 MiB/9.80 MiB
# ⠴ Preparing packages... (13/16)
# transformers ------------------------------ 2.86 MiB/9.80 MiB
# ⠦ Preparing packages... (14/16)
# transformers ------------------------------ 3.24 MiB/9.80 MiB
# ⠦ Preparing packages... (14/16)
# transformers ------------------------------ 3.64 MiB/9.80 MiB
# ⠦ Preparing packages... (14/16)
# ⠦ Preparing packages... (14/16)
# ⠦ Preparing packages... (14/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠧ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠇ Preparing packages... (15/16)
# ⠋ Preparing packages... (15/16)
# Prepared 16 packages in 3.45s
# Uninstalled 5 packages in 823ms
# Installed 16 packages in 498ms
#  + annotated-doc==0.0.4
#  + bitsandbytes==0.49.1
#  + datasets==4.5.0
#  + dill==0.4.0
#  + evaluate==0.4.6
#  - hf-xet==1.1.9
#  + hf-xet==1.2.0
#  - huggingface-hub==0.34.4
#  + huggingface-hub==1.4.1
#  + multiprocess==0.70.18
#  + peft==0.18.1
#  + pyarrow==23.0.0
#  - tokenizers==0.22.0
#  + tokenizers==0.22.2
#  - transformers==4.56.0
#  + transformers==5.1.0
#  + trl==0.28.0
#  - typer==0.17.3
#  + typer==0.23.1
#  + typer-slim==0.23.1
#  + xxhash==3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Verify correct Pytorch version
import torch
print(f"PyTorch: {torch.__version__}")  # Should show 2.9.0+cu128, NOT 2.10.0
# Out:
# PyTorch: 2.9.0+cu128

# %% [markdown]
# ## Load DentalGemma Datasets
#
# We use two purpose-built datasets from HuggingFace Hub:
#
# | Dataset | Type | Samples | Tasks |
# |:--------|:-----|--------:|:------|
# | `dentalgemma-vqa` | Multimodal (image + text) | 1,654 | Cavity detection, OPG classification, tooth ID, radiograph assessment |
# | `dentalgemma-instruct` | Text-only | 2,494 | Clinical case assessment across 98 dental conditions |
#
# Both datasets are pre-formatted in chat template format (system/user/assistant) compatible with MedGemma's expected input.

# %%
from datasets import load_dataset

vqa_data = load_dataset("naazimsnh02/dentalgemma-vqa")
instruct_data = load_dataset("naazimsnh02/dentalgemma-instruct")

print("=" * 50)
print("DentalGemma VQA (Multimodal):")
print(vqa_data)
print("\nDentalGemma Instruct (Text-only):")
print(instruct_data)
# Out:
# README.md:   0%|          | 0.00/2.59k [00:00<?, ?B/s]
# data/train-00000-of-00002.parquet:   0%|          | 0.00/276M [00:00<?, ?B/s]
# data/train-00001-of-00002.parquet:   0%|          | 0.00/255M [00:00<?, ?B/s]
# data/validation-00000-of-00001.parquet:   0%|          | 0.00/54.8M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1488 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/166 [00:00<?, ? examples/s]
# README.md:   0%|          | 0.00/1.78k [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/863k [00:00<?, ?B/s]
# data/validation-00000-of-00001.parquet:   0%|          | 0.00/105k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2244 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/250 [00:00<?, ? examples/s]
# ==================================================
# DentalGemma VQA (Multimodal):
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'messages', 'source', 'condition'],
#         num_rows: 1488
#     })
#     validation: Dataset({
#         features: ['image', 'messages', 'source', 'condition'],
#         num_rows: 166
#     })
# })
#
# DentalGemma Instruct (Text-only):
# DatasetDict({
#     train: Dataset({
#         features: ['messages', 'source', 'condition'],
#         num_rows: 2244
#     })
#     validation: Dataset({
#         features: ['messages', 'source', 'condition'],
#         num_rows: 250
#     })
# })

# %% [markdown]
# ### Inspect VQA samples
#
# Each VQA sample contains:
# - `image`: dental X-ray as a PIL Image
# - `messages`: JSON string with chat-format messages (system/user[image+text]/assistant)
# - `source`: origin dataset tag
# - `condition`: dental condition label

# %%
import json
from collections import Counter

sample = vqa_data["train"][0]
print("Image size:", sample["image"].size)
print("Source:", sample["source"])
print("Condition:", sample["condition"])
print("\nMessages:")
messages = json.loads(sample["messages"])
for msg in messages:
    role = msg["role"]
    if isinstance(msg["content"], list):
        types = [c["type"] for c in msg["content"]]
        print(f"  {role}: [{', '.join(types)}]")
    else:
        print(f"  {role}: {msg['content'][:120]}...")

print("\n--- Source distribution (train) ---")
for src, cnt in sorted(Counter(vqa_data["train"]["source"]).items()):
    print(f"  {src}: {cnt}")
# Out:
# Image size: (1024, 512)
# Source: panoramic_dental_xray
# Condition: general
#
# Messages:
#   system: You are an expert dental clinician and radiologist AI assistant. Analyze dental images and clinical information to provi...
#   user: [image, text]
#   assistant: This dental X-ray shows the following tooth types: 1 third molar, 3 second molars, 2 first molars, 4 second premolars, 3...
#
# --- Source distribution (train) ---
#   dental_cavity_detection: 380
#   dental_opg_classification: 470
#   dental_radiography: 584
#   panoramic_dental_xray: 54

# %%
# Display a sample dental X-ray
vqa_data["train"][0]["image"]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x512>

# %%
# Display a sample dental X-ray details
vqa_data["train"][0]
# Out:
# {'image': <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x512>,
#  'messages': '[{"role": "system", "content": "You are an expert dental clinician and radiologist AI assistant. Analyze dental images and clinical information to provide accurate, evidence-based assessments. Always recommend clinical correlation and professional evaluation for definitive diagnosis."}, {"role": "user", "content": [{"type": "image"}, {"type": "text", "text": "Classify the teeth visible in this dental image."}]}, {"role": "assistant", "content": "This dental X-ray shows the following tooth types: 1 third molar, 3 second molars, 2 first molars, 4 second premolars, 3 first premolars, 4 canines, 4 lateral incisors, 4 central incisors. Each tooth type has distinct morphology - incisors for cutting, canines for tearing, premolars for crushing, and molars for grinding. The identification of tooth types is essential for dental charting, treatment planning, and forensic odontology."}]',
#  'source': 'panoramic_dental_xray',
#  'condition': 'general'}

# %% [markdown]
# ### Inspect instruct samples

# %%
sample = instruct_data["train"][0]
print("Source:", sample["source"])
print("Condition:", sample["condition"])
print("\nMessages:")
messages = json.loads(sample["messages"])
for msg in messages:
    print(f"  {msg['role']}: {str(msg['content'])[:150]}...")

print(f"\nUnique conditions: {len(set(instruct_data['train']['condition']))}")
# Out:
# Source: wildstash_dental_instruct
# Condition: Suspicious oral mucosal lesion requiring biopsy
#
# Messages:
#   system: You are an expert dental clinician providing comprehensive patient care. Always consider the patient's full clinical context, medical history, and pro...
#   user: Please evaluate this dental patient:
#
# PATIENT: Suspicious oral mucosal lesion requiring biopsy
# AGE: 60 years old
# SEX: female
# OCCUPATION: consultant
#
# C...
#   assistant: ## Patient Assessment
#
#
#
# **Diagnosis:** Suspicious oral mucosal lesion requiring biopsy
# **Etiology:** neoplastic_suspicious
# **Urgency:** Urgent (2)
#
# #...
#
# Unique conditions: 92

# %% [markdown]
# ### Format datasets for training
#
# Parse the JSON `messages` field into Python objects for the chat template collator. The VQA dataset has multimodal message format (image + text); the instruct dataset has text-only messages.
#
# **Note:** MedGemma 1.5 expects system content as `[{"type": "text", "text": "..."}]` list format (see the [official quick start notebook](https://github.com/google-health/medgemma)). We normalize our stored string-format system messages to match.

# %%
import json
from typing import Any


def _normalize_messages(messages: list[dict]) -> list[dict]:
    """Ensure system content uses the list-of-dicts format MedGemma expects.

    MedGemma 1.5 chat template expects:
      {"role": "system", "content": [{"type": "text", "text": "..."}]}
    Our datasets store system content as a plain string.
    """
    normalized = []
    for msg in messages:
        if msg["role"] == "system" and isinstance(msg["content"], str):
            normalized.append({
                "role": "system",
                "content": [{"type": "text", "text": msg["content"]}],
            })
        elif msg["role"] == "assistant" and isinstance(msg["content"], str):
            normalized.append({
                "role": "assistant",
                "content": [{"type": "text", "text": msg["content"]}],
            })
        else:
            normalized.append(msg)
    return normalized


def parse_vqa_messages(example: dict[str, Any]) -> dict[str, Any]:
    """Parse JSON messages and normalize for MedGemma's chat template."""
    example["messages"] = _normalize_messages(json.loads(example["messages"]))
    return example


def parse_instruct_messages(example: dict[str, Any]) -> dict[str, Any]:
    """Parse JSON messages and normalize for MedGemma's chat template.

    Instruct messages are text-only, so user content is wrapped in
    [{"type": "text", "text": "..."}] to match the expected format.
    """
    raw = json.loads(example["messages"])
    normalized = []
    for msg in raw:
        if isinstance(msg["content"], str):
            normalized.append({
                "role": msg["role"],
                "content": [{"type": "text", "text": msg["content"]}],
            })
        else:
            normalized.append(msg)
    example["messages"] = normalized
    return example


vqa_data = vqa_data.map(parse_vqa_messages)
instruct_data = instruct_data.map(parse_instruct_messages)

print("VQA train sample messages (parsed):")
sample_msgs = vqa_data['train'][0]['messages']
for m in sample_msgs:
    if isinstance(m['content'], list):
        print(f"  {m['role']}: [{', '.join(c['type'] for c in m['content'])}]")
    else:
        print(f"  {m['role']}: {str(m['content'])[:80]}...")

print(f"\nInstruct train sample messages (parsed):")
sample_msgs = instruct_data['train'][0]['messages']
for m in sample_msgs:
    if isinstance(m['content'], list):
        print(f"  {m['role']}: [{', '.join(c['type'] for c in m['content'])}]")
    else:
        print(f"  {m['role']}: {str(m['content'])[:80]}...")
# Out:
# Map:   0%|          | 0/1488 [00:00<?, ? examples/s]
# Map:   0%|          | 0/166 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2244 [00:00<?, ? examples/s]
# Map:   0%|          | 0/250 [00:00<?, ? examples/s]
# VQA train sample messages (parsed):
#   system: [text]
#   user: [image, text]
#   assistant: [text]
#
# Instruct train sample messages (parsed):
#   system: [text]
#   user: [text]
#   assistant: [text]

# %% [markdown]
# ## Fine-tune with LoRA
#
# We use Low-Rank Adaptation (LoRA) to fine-tune MedGemma efficiently:
#
# - **Full bfloat16 precision** — no quantization for maximum training quality
# - **LoRA adapters** (rank 64, alpha 64) attached to attention and MLP layers
# - **Only adapter parameters are updated** — the base model stays frozen
#
# This allows fine-tuning a 4B parameter model on a single A100 GPU.

# %% [markdown]
# ### Load MedGemma with 4-bit quantization

# %%
import torch
from transformers import AutoProcessor, AutoModelForImageTextToText, BitsAndBytesConfig

model_id = "google/medgemma-1.5-4b-it"

if torch.cuda.get_device_capability()[0] < 8:
    raise ValueError("GPU does not support bfloat16. Please use an A100 or newer GPU.")

model_kwargs = dict(
    attn_implementation="eager",
    torch_dtype=torch.bfloat16,
    device_map="auto",
)

model_kwargs["quantization_config"] = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=model_kwargs["torch_dtype"],
    bnb_4bit_quant_storage=model_kwargs["torch_dtype"],
)

model = AutoModelForImageTextToText.from_pretrained(model_id, **model_kwargs)
processor = AutoProcessor.from_pretrained(model_id)
processor.tokenizer.padding_side = "right"

print(f"Model loaded: {model_id}")
print(f"Quantization: 4-bit NF4 with double quantization")

# %%
import torch
from transformers import AutoProcessor, AutoModelForImageTextToText

model_id = "google/medgemma-1.5-4b-it"

# Check for A100/H100/Ampere or newer for best performance with bfloat16
if torch.cuda.get_device_capability()[0] < 8:
    print("Warning: GPU capabilities < 8. bfloat16 might not be supported or slow.")
else:
    print("High-performance GPU detected (Ampere+). Using native bfloat16.")

# Load Full Model in bfloat16 (No Quantization)
model_kwargs = dict(
    attn_implementation="eager",
    torch_dtype=torch.bfloat16,
    device_map="auto",
)


model = AutoModelForImageTextToText.from_pretrained(model_id, **model_kwargs)
processor = AutoProcessor.from_pretrained(model_id)
processor.tokenizer.padding_side = "right"

print(f"Model loaded: {model_id}")
print(f"Precision: Full bfloat16 (No Quantization)")
# Out:
# High-performance GPU detected (Ampere+). Using native bfloat16.
# config.json:   0%|          | 0.00/2.55k [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json:   0%|          | 0.00/90.6k [00:00<?, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/883 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/115 [00:00<?, ?B/s]
# processor_config.json:   0%|          | 0.00/70.0 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# The image processor of type `Gemma3ImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# Model loaded: google/medgemma-1.5-4b-it
# Precision: Full bfloat16 (No Quantization)

# %% [markdown]
# ### Configure LoRA

# %%
from peft import LoraConfig

peft_config = LoraConfig(
    lora_alpha=64,
    lora_dropout=0.05,
    r=64,
    bias="none",
    target_modules="all-linear",
    task_type="CAUSAL_LM",
    modules_to_save=[
        "lm_head",
        "embed_tokens",
    ],
)

# %% [markdown]
# ### Data collators
#
# We define separate collators for the multimodal VQA data (with images) and the text-only instruct data. Both use `processor.apply_chat_template` to format messages into the model's expected input format.

# %%
from typing import Any
import torch

# Enable padding to prevent aspect ratio distortion
if hasattr(processor, "image_processor"):
    if hasattr(processor.image_processor, "do_pad"):
        processor.image_processor.do_pad = True
        print("Enabled padding for image processor.")
    else:
        print("Warning: do_pad not found in image_processor config")

def vqa_collate_fn(examples: list[dict[str, Any]]):
    """Collator for multimodal VQA examples (image + text)."""
    texts = []
    images = []
    for example in examples:
        images.append([example["image"].convert("RGB")])
        texts.append(processor.apply_chat_template(
            example["messages"], add_generation_prompt=False, tokenize=False
        ).strip())

    batch = processor(text=texts, images=images, return_tensors="pt", padding=True)

    # Initialize labels with -100 (masked)
    labels = torch.full_like(batch["input_ids"], -100)
    
    # Iterate through batch to mask user prompts
    for i in range(len(batch["input_ids"])):
        input_ids = batch["input_ids"][i]
        input_list = input_ids.tolist()
        
        # Find start of assistant turn: <start_of_turn>model
        # Tokens: 105 (start_of_turn), 4368 (model)
        start_idx = -1
        for j in range(len(input_list) - 1):
            if input_list[j] == 105 and input_list[j+1] == 4368:
                start_idx = j + 2
                break
        
        if start_idx != -1:
            # Skip potential newline (107)
            if start_idx < len(input_list) and input_list[start_idx] == 107:
                start_idx += 1
            
            # Unmask response
            labels[i, start_idx:] = input_ids[start_idx:]

    # Ensure padding is ignored
    labels[batch["input_ids"] == processor.tokenizer.pad_token_id] = -100

    batch["labels"] = labels
    return batch


def instruct_collate_fn(examples: list[dict[str, Any]]):
    """Collator for text-only instruct examples."""
    texts = []
    for example in examples:
        texts.append(processor.apply_chat_template(
            example["messages"], add_generation_prompt=False, tokenize=False
        ).strip())

    batch = processor.tokenizer(
        texts, return_tensors="pt", padding=True, truncation=True, max_length=1024
    )

    labels = torch.full_like(batch["input_ids"], -100)
    
    for i in range(len(batch["input_ids"])):
        input_ids = batch["input_ids"][i]
        input_list = input_ids.tolist()
        
        start_idx = -1
        for j in range(len(input_list) - 1):
            if input_list[j] == 105 and input_list[j+1] == 4368:
                start_idx = j + 2
                break
        
        if start_idx != -1:
            if start_idx < len(input_list) and input_list[start_idx] == 107:
                start_idx += 1
            labels[i, start_idx:] = input_ids[start_idx:]

    labels[batch["input_ids"] == processor.tokenizer.pad_token_id] = -100
    batch["labels"] = labels
    
    # Add token_type_ids for Gemma3 training
    if "token_type_ids" not in batch:
        batch["token_type_ids"] = torch.zeros_like(batch["input_ids"])
    
    return batch
# Out:
# Enabled padding for image processor.

# %% [markdown]
# ## Stage 1: Fine-tune on VQA Dataset (Multimodal)
#
# First, we train on the multimodal VQA dataset containing dental X-ray images paired with clinical questions and answers. This teaches the model to:
# - Detect cavities and count regions in intraoral X-rays
# - Classify dental pathologies from panoramic X-rays (6 classes)
# - Identify and count tooth types from panoramic radiographs
# - Perform systematic radiographic assessments
#
# **Checkpointing:** Model checkpoints are saved every 100 steps and at each epoch to prevent data loss during long training runs.

# %%
def verify_template_and_config():
    """Verification of chat template."""
    print("\n--- Verifying Chat Template ---")
    messages = [
        {"role": "user", "content": "Hello"},
        {"role": "model", "content": "Hi there"}
    ]
    prompt = processor.apply_chat_template(messages, tokenize=False, add_generation_prompt=False)
    print("Template Output:")
    print(prompt)
    
    tokens = processor.tokenizer.encode(prompt, add_special_tokens=False)
    decoded = [processor.tokenizer.decode([t]) for t in tokens]
    print(f"\nTokens: {tokens}")
    print(f"Decoded: {decoded}")
    
    # Verify key tokens for label masking
    print("\n--- Key Token IDs for Label Masking ---")
    print(f"<start_of_turn>: {processor.tokenizer.encode('<start_of_turn>', add_special_tokens=False)}")
    print(f"'model': {processor.tokenizer.encode('model', add_special_tokens=False)}")
    print(f"Newline: {processor.tokenizer.encode(chr(10), add_special_tokens=False)}")
    
    # These should match the hardcoded values in vqa_collate_fn
    start_of_turn_id = processor.tokenizer.encode('<start_of_turn>', add_special_tokens=False)[0]
    model_id = processor.tokenizer.encode('model', add_special_tokens=False)[0]
    
    if start_of_turn_id == 105 and model_id == 4368:
        print("\n✅ Token IDs match collator expectations (105, 4368)")
    else:
        print(f"\n⚠️ WARNING: Token IDs don't match!")
        print(f"   Expected: 105, 4368")
        print(f"   Got: {start_of_turn_id}, {model_id}")
        print(f"   Update vqa_collate_fn with correct IDs!")
    
    print("\n✅ Verification Complete.")

verify_template_and_config()
# Out:
# --- Verifying Chat Template ---
# Template Output:
# <bos><start_of_turn>user
# Hello<end_of_turn>
# <start_of_turn>model
# Hi there<end_of_turn>
#
#
# Tokens: [2, 105, 2364, 107, 9259, 106, 107, 105, 4368, 107, 10979, 993, 106, 107]
# Decoded: ['<bos>', '<start_of_turn>', 'user', '\n', 'Hello', '<end_of_turn>', '\n', '<start_of_turn>', 'model', '\n', 'Hi', ' there', '<end_of_turn>', '\n']
#
# --- Key Token IDs for Label Masking ---
# <start_of_turn>: [105]
# 'model': [4368]
# Newline: [107]
#
# ✅ Token IDs match collator expectations (105, 4368)
#
# ✅ Verification Complete.

# %%
from trl import SFTConfig

output_dir = "dentalgemma-1.5-4b-it-vqa"  # @param {type: "string"}
num_train_epochs = 10  # @param {type: "number"}
learning_rate = 5e-5  # @param {type: "number"}

vqa_training_args = SFTConfig(
    output_dir=output_dir,
    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=1,
    per_device_eval_batch_size=1,
    gradient_accumulation_steps=4,
    gradient_checkpointing=True,
    optim="adamw_torch_fused",
    logging_steps=25,
    save_strategy="steps",
    save_steps=100,
    save_total_limit=10,
    eval_strategy="steps",
    eval_steps=100,
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,
    learning_rate=learning_rate,
    bf16=True,
    max_grad_norm=1.0,
    warmup_ratio=0.1,
    lr_scheduler_type="linear",
    push_to_hub=False,
    report_to="tensorboard",
    gradient_checkpointing_kwargs={"use_reentrant": False},
    dataset_kwargs={"skip_prepare_dataset": True},
    remove_unused_columns=False,
    label_names=["labels"],
)
# Out:
# warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.

# %%
from trl import SFTTrainer

vqa_trainer = SFTTrainer(
    model=model,
    args=vqa_training_args,
    train_dataset=vqa_data["train"],
    eval_dataset=vqa_data["validation"],
    peft_config=peft_config,
    processing_class=processor,
    data_collator=vqa_collate_fn,
)
# Out:
# /usr/local/lib/python3.12/site-packages/peft/tuners/tuners_utils.py:1225: UserWarning: Model has `tie_word_embeddings=True` and a tied layer is part of the adapter, but `ensure_weight_tying` is not set to True. This can lead to complications, for example when merging the adapter or converting your model to formats other than safetensors. Check the discussion here: https://github.com/huggingface/peft/issues/2777
#   warnings.warn(msg)
# Detected kernel version 4.4.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.

# %% [markdown]
# ### Train on VQA data
#
# Training resumes automatically from the latest checkpoint if one exists in the output directory.

# %%
import os

# Resume from checkpoint if available
vqa_checkpoint = None
if os.path.isdir(output_dir):
    checkpoints = [d for d in os.listdir(output_dir) if d.startswith("checkpoint-")]
    if checkpoints:
        latest = sorted(checkpoints, key=lambda x: int(x.split("-")[1]))[-1]
        vqa_checkpoint = os.path.join(output_dir, latest)
        print(f"Resuming VQA training from: {vqa_checkpoint}")

vqa_trainer.train(resume_from_checkpoint=vqa_checkpoint)
# Out:
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 1, 'bos_token_id': 2, 'pad_token_id': 0}.
#     <div>
#
#       <progress value='2078' max='3720' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2078/3720 4:23:01 < 3:28:01, 0.13 it/s, Epoch 5.58/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.454626</td>
#       <td>0.207423</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.054255</td>
#       <td>0.048761</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.045850</td>
#       <td>0.051590</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.034577</td>
#       <td>0.040259</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.036318</td>
#       <td>0.036398</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.029235</td>
#       <td>0.034996</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.035213</td>
#       <td>0.029132</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.023721</td>
#       <td>0.031713</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.022592</td>
#       <td>0.030690</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.024699</td>
#       <td>0.029219</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.025887</td>
#       <td>0.029635</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.026059</td>
#       <td>0.028134</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.019152</td>
#       <td>0.029536</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.020461</td>
#       <td>0.033676</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.022410</td>
#       <td>0.031741</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.021005</td>
#       <td>0.029406</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.027951</td>
#       <td>0.030057</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.023186</td>
#       <td>0.029480</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.016187</td>
#       <td>0.030744</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.019440</td>
#       <td>0.032428</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 12
#       9         vqa_checkpoint = os.path.join(output_dir, latest)
#      10         print(f"Resuming VQA training from: {vqa_checkpoint}")
# ---> 12 vqa_trainer.train(resume_from_checkpoint=vqa_checkpoint)
#
# File /usr/local/lib/python3.12/site-packages/transformers/trainer.py:2170, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2168         hf_hub_utils.enable_progress_bars()
#    2169 else:
# -> 2170     return inner_training_loop(
#    2171         args=args,
#    2172         resume_from_checkpoint=resume_from_checkpoint,
#    2173         trial=trial,
#    2174         ignore_keys_for_eval=ignore_keys_for_eval,
#    2175     )
#
# File /usr/local/lib/python3.12/site-packages/transformers/trainer.py:2537, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2530 context = (
#    2531     functools.partial(self.accelerator.no_sync, model=model)
#    2532     if i != len(batch_samples) - 1
#    2533     and self.accelerator.distributed_type != DistributedType.DEEPSPEED
#    2534     else contextlib.nullcontext
#    2535 )
#    2536 with context():
# -> 2537     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2539 if (
#    2540     args.logging_nan_inf_filter
#    2541     and not is_torch_xla_available()
#    2542     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2543 ):
#    2544     # if loss is nan or inf simply add the average of previous logged losses
#    2545     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File /usr/local/lib/python3.12/site-packages/trl/trainer/sft_trainer.py:1290, in SFTTrainer.training_step(self, *args, **kwargs)
#    1288 def training_step(self, *args, **kwargs):
#    1289     with self.maybe_activation_offload_context:
# -> 1290         return super().training_step(*args, **kwargs)
#
# File /usr/local/lib/python3.12/site-packages/transformers/trainer.py:3838, in Trainer.training_step(***failed resolving arguments***)
#    3835 if self.accelerator.distributed_type == DistributedType.DEEPSPEED:
#    3836     kwargs["scale_wrt_gas"] = False
# -> 3838 self.accelerator.backward(loss, **kwargs)
#    3840 return loss.detach()
#
# File /usr/local/lib/python3.12/site-packages/accelerate/accelerator.py:2734, in Accelerator.backward(self, loss, **kwargs)
#    2732     self.lomo_backward(loss, learning_rate)
#    2733 else:
# -> 2734     loss.backward(**kwargs)
#
# File /usr/local/lib/python3.12/site-packages/torch/_tensor.py:625, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     615 if has_torch_function_unary(self):
#     616     return handle_torch_function(
#     617         Tensor.backward,
#     618         (self,),
#    (...)    623         inputs=inputs,
#     624     )
# --> 625 torch.autograd.backward(
#     626     self, gradient, retain_graph, create_graph, inputs=inputs
#     627 )
#
# File /usr/local/lib/python3.12/site-packages/torch/autograd/__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File /usr/local/lib/python3.12/site-packages/torch/autograd/graph.py:841, in _engine_run_backward(t_outputs, *args, **kwargs)
#     839     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840 try:
# --> 841     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842         t_outputs, *args, **kwargs
#     843     )  # Calls into the C++ engine to run the backward pass
#     844 finally:
#     845     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
import os
from peft import PeftModel

# Load the best checkpoint (step 1200 - lowest val loss: 0.0281)
best_checkpoint = "checkpoint-1200"
best_checkpoint_path = os.path.join(output_dir, best_checkpoint)

if os.path.exists(best_checkpoint_path):
    print(f"✅ Loading best VQA checkpoint: {best_checkpoint}")
    print(f"   Path: {best_checkpoint_path}")
    print(f"   Validation loss: 0.0281 (best)")
    
    # Load the best checkpoint into the trainer's model
    # This replaces the current model with the best one
    vqa_trainer.model.load_adapter(best_checkpoint_path, adapter_name="default")
    
    # Save the best checkpoint as the final VQA adapter
    vqa_trainer.save_model()
    print(f"✅ Best VQA adapter saved to: {output_dir}")
    
    # Verify what was saved
    saved_files = os.listdir(output_dir)
    adapter_files = [f for f in saved_files if f.endswith('.safetensors') or f == 'adapter_config.json']
    print(f"✅ Saved adapter files: {adapter_files}")
    
else:
    print(f"❌ Checkpoint not found: {best_checkpoint_path}")
    print("Available checkpoints:")
    checkpoints = [d for d in os.listdir(output_dir) if d.startswith("checkpoint-")]
    for cp in sorted(checkpoints, key=lambda x: int(x.split("-")[1])):
        print(f"  - {cp}")
# Out:
# ✅ Loading best VQA checkpoint: checkpoint-1200
#    Path: dentalgemma-1.5-4b-it-vqa/checkpoint-1200
#    Validation loss: 0.0281 (best)
# ✅ Best VQA adapter saved to: dentalgemma-1.5-4b-it-vqa
# ✅ Saved adapter files: ['adapter_model.safetensors', 'adapter_config.json']

# %% [markdown]
# ## Stage 2: Fine-tune on Instruct Dataset (Text-only)
#
# Next, we continue training on the text-only clinical instruct dataset. This teaches the model structured clinical reasoning:
# - Diagnosis from patient history and symptoms
# - Treatment planning with management protocols
# - Antibiotic considerations
# - Follow-up scheduling and patient counseling
#
# The LoRA adapter from Stage 1 is carried forward so the model retains its visual capabilities while gaining clinical text reasoning.

# %%
instruct_output_dir = "dentalgemma-1.5-4b-it-instruct"  # @param {type: "string"}

instruct_training_args = SFTConfig(
    output_dir=instruct_output_dir,
    num_train_epochs=10,
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    gradient_accumulation_steps=4,
    gradient_checkpointing=True,
    optim="adamw_torch_fused",
    logging_steps=25,
    save_strategy="steps",
    save_steps=100,
    save_total_limit=3,
    eval_strategy="steps",
    eval_steps=100,
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,
    learning_rate=5e-5,
    bf16=True,
    max_grad_norm=1.0,
    warmup_ratio=0.1,
    lr_scheduler_type="linear",
    push_to_hub=False,
    report_to="tensorboard",
    gradient_checkpointing_kwargs={"use_reentrant": False},
    dataset_kwargs={"skip_prepare_dataset": True},
    remove_unused_columns=False,
    label_names=["labels"],
)
# Out:
# warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.

# %%
instruct_trainer = SFTTrainer(
    model=vqa_trainer.model,
    args=instruct_training_args,
    train_dataset=instruct_data["train"],
    eval_dataset=instruct_data["validation"],
    processing_class=processor.tokenizer,
    data_collator=instruct_collate_fn,
)
# Out:
# Detected kernel version 4.4.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.

# %% [markdown]
# ### Train on instruct data

# %%
# Resume from checkpoint if available
instruct_checkpoint = None
if os.path.isdir(instruct_output_dir):
    checkpoints = [d for d in os.listdir(instruct_output_dir) if d.startswith("checkpoint-")]
    if checkpoints:
        latest = sorted(checkpoints, key=lambda x: int(x.split("-")[1]))[-1]
        instruct_checkpoint = os.path.join(instruct_output_dir, latest)
        print(f"Resuming instruct training from: {instruct_checkpoint}")

instruct_trainer.train(resume_from_checkpoint=instruct_checkpoint)

instruct_trainer.save_model()
print(f"Instruct adapter saved to: {instruct_output_dir}")
# Out:
#     <div>
#
#       <progress value='902' max='2810' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 902/2810 1:06:04 < 2:20:04, 0.23 it/s, Epoch 3.21/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.498206</td>
#       <td>0.344789</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.087281</td>
#       <td>0.056524</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.028144</td>
#       <td>0.040902</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.018044</td>
#       <td>0.030326</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.007279</td>
#       <td>0.022449</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.008179</td>
#       <td>0.021124</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.003967</td>
#       <td>0.020886</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.003019</td>
#       <td>0.022946</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.003784</td>
#       <td>0.023212</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 10
#       7         instruct_checkpoint = os.path.join(instruct_output_dir, latest)
#       8         print(f"Resuming instruct training from: {instruct_checkpoint}")
# ---> 10 instruct_trainer.train(resume_from_checkpoint=instruct_checkpoint)
#      12 instruct_trainer.save_model()
#      13 print(f"Instruct adapter saved to: {instruct_output_dir}")
#
# File /usr/local/lib/python3.12/site-packages/transformers/trainer.py:2170, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2168         hf_hub_utils.enable_progress_bars()
#    2169 else:
# -> 2170     return inner_training_loop(
#    2171         args=args,
#    2172         resume_from_checkpoint=resume_from_checkpoint,
#    2173         trial=trial,
#    2174         ignore_keys_for_eval=ignore_keys_for_eval,
#    2175     )
#
# File /usr/local/lib/python3.12/site-packages/transformers/trainer.py:2537, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2530 context = (
#    2531     functools.partial(self.accelerator.no_sync, model=model)
#    2532     if i != len(batch_samples) - 1
#    2533     and self.accelerator.distributed_type != DistributedType.DEEPSPEED
#    2534     else contextlib.nullcontext
#    2535 )
#    2536 with context():
# -> 2537     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2539 if (
#    2540     args.logging_nan_inf_filter
#    2541     and not is_torch_xla_available()
#    2542     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2543 ):
#    2544     # if loss is nan or inf simply add the average of previous logged losses
#    2545     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File /usr/local/lib/python3.12/site-packages/trl/trainer/sft_trainer.py:1290, in SFTTrainer.training_step(self, *args, **kwargs)
#    1288 def training_step(self, *args, **kwargs):
#    1289     with self.maybe_activation_offload_context:
# -> 1290         return super().training_step(*args, **kwargs)
#
# File /usr/local/lib/python3.12/site-packages/transformers/trainer.py:3838, in Trainer.training_step(***failed resolving arguments***)
#    3835 if self.accelerator.distributed_type == DistributedType.DEEPSPEED:
#    3836     kwargs["scale_wrt_gas"] = False
# -> 3838 self.accelerator.backward(loss, **kwargs)
#    3840 return loss.detach()
#
# File /usr/local/lib/python3.12/site-packages/accelerate/accelerator.py:2734, in Accelerator.backward(self, loss, **kwargs)
#    2732     self.lomo_backward(loss, learning_rate)
#    2733 else:
# -> 2734     loss.backward(**kwargs)
#
# File /usr/local/lib/python3.12/site-packages/torch/_tensor.py:625, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     615 if has_torch_function_unary(self):
#     616     return handle_torch_function(
#     617         Tensor.backward,
#     618         (self,),
#    (...)    623         inputs=inputs,
#     624     )
# --> 625 torch.autograd.backward(
#     626     self, gradient, retain_graph, create_graph, inputs=inputs
#     627 )
#
# File /usr/local/lib/python3.12/site-packages/torch/autograd/__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File /usr/local/lib/python3.12/site-packages/torch/autograd/graph.py:841, in _engine_run_backward(t_outputs, *args, **kwargs)
#     839     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840 try:
# --> 841     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842         t_outputs, *args, **kwargs
#     843     )  # Calls into the C++ engine to run the backward pass
#     844 finally:
#     845     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
import os

# Load the best checkpoint (step 700 - lowest val loss: 0.020886)
best_checkpoint = "checkpoint-700"
best_checkpoint_path = os.path.join(instruct_output_dir, best_checkpoint)

if os.path.exists(best_checkpoint_path):
    print(f"✅ Loading best Instruct checkpoint: {best_checkpoint}")
    print(f"   Path: {best_checkpoint_path}")
    print(f"   Validation loss: 0.020886 (best)")
    
    # Load the best checkpoint into the trainer's model
    instruct_trainer.model.load_adapter(best_checkpoint_path, adapter_name="default")
    
    # Save the best checkpoint as the final Instruct adapter
    instruct_trainer.save_model()
    print(f"✅ Best Instruct adapter saved to: {instruct_output_dir}")
    
    # Verify what was saved
    saved_files = os.listdir(instruct_output_dir)
    adapter_files = [f for f in saved_files if f.endswith('.safetensors') or f == 'adapter_config.json']
    print(f"✅ Saved adapter files: {adapter_files}")
    
else:
    print(f"❌ Checkpoint not found: {best_checkpoint_path}")
    print("Available checkpoints:")
    checkpoints = [d for d in os.listdir(instruct_output_dir) if d.startswith("checkpoint-")]
    for cp in sorted(checkpoints, key=lambda x: int(x.split("-")[1])):
        print(f"  - {cp}")
# Out:
# ✅ Loading best Instruct checkpoint: checkpoint-700
#    Path: dentalgemma-1.5-4b-it-instruct/checkpoint-700
#    Validation loss: 0.020886 (best)
# ✅ Best Instruct adapter saved to: dentalgemma-1.5-4b-it-instruct
# ✅ Saved adapter files: ['adapter_model.safetensors', 'adapter_config.json']

# %% [markdown]
# ## Merge LoRA Adapter & Push to Hub
#
# Merge the trained LoRA adapter weights into the base model to create a standalone model that can be used without PEFT, then push the merged model and processor to HuggingFace Hub.

# %%
from peft import PeftModel
from transformers import AutoModelForImageTextToText

model_id = "google/medgemma-1.5-4b-it"

# Reload the base model in full precision for merging
print("Loading base model for merge...")
base_model = AutoModelForImageTextToText.from_pretrained(
    model_id,
    torch_dtype=torch.bfloat16,
    device_map="auto",
)
print(f"✅ Base model loaded: {model_id}")

# Load the fine-tuned LoRA adapter (best checkpoint-700)
print(f"\nLoading LoRA adapter from: {instruct_output_dir}")
merged_model = PeftModel.from_pretrained(base_model, instruct_output_dir)
print(f"✅ LoRA adapter loaded")

# Merge LoRA weights into the base model
print("\nMerging LoRA adapter into base model...")
merged_model = merged_model.merge_and_unload()
print("✅ Merge complete!")

# Verify merged model
print(f"\n📊 Merged model type: {type(merged_model)}")
print(f"📊 Model device: {next(merged_model.parameters()).device}")
print(f"📊 Model dtype: {next(merged_model.parameters()).dtype}")
# Out:
# Loading base model for merge...
# Loading weights:   0%|          | 0/883 [00:00<?, ?it/s]
# ✅ Base model loaded: google/medgemma-1.5-4b-it
#
# Loading LoRA adapter from: dentalgemma-1.5-4b-it-instruct
# /usr/local/lib/python3.12/site-packages/peft/tuners/tuners_utils.py:1225: UserWarning: Model has `tie_word_embeddings=True` and a tied layer is part of the adapter, but `ensure_weight_tying` is not set to True. This can lead to complications, for example when merging the adapter or converting your model to formats other than safetensors. Check the discussion here: https://github.com/huggingface/peft/issues/2777
#   warnings.warn(msg)
# ✅ LoRA adapter loaded
#
# Merging LoRA adapter into base model...
# ✅ Merge complete!
#
# 📊 Merged model type: <class 'transformers.models.gemma3.modeling_gemma3.Gemma3ForConditionalGeneration'>
# 📊 Model device: cuda:0
# 📊 Model dtype: torch.bfloat16

# %%
# Set your HuggingFace repo ID
hub_repo_id = "naazimsnh02/dentalgemma-1.5-4b-it"  # @param {type: "string"}

print(f"\n🚀 Pushing merged model to: {hub_repo_id}")

try:
    # Push model
    merged_model.push_to_hub(
        hub_repo_id, 
        private=False,
        commit_message="DentalGemma 1.5 4B IT - Fine-tuned on dental VQA and clinical instruct data"
    )
    print(f"✅ Model pushed successfully!")
    
    # Push processor
    processor.push_to_hub(
        hub_repo_id,
        commit_message="Add processor for DentalGemma"
    )
    print(f"✅ Processor pushed successfully!")
    
    print(f"\n🎉 Complete! Model available at:")
    print(f"   https://huggingface.co/{hub_repo_id}")
    
except Exception as e:
    print(f"❌ Error pushing to hub: {e}")
    print("\nTrying to save locally instead...")
    
    # Save locally as backup
    local_output = "dentalgemma-1.5-4b-it-merged"
    merged_model.save_pretrained(local_output)
    processor.save_pretrained(local_output)
    print(f"✅ Model saved locally to: {local_output}")
# Out:
# 🚀 Pushing merged model to: naazimsnh02/dentalgemma-1.5-4b-it
# README.md:   0%|          | 0.00/14.6k [00:00<?, ?B/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# ✅ Model pushed successfully!
# README.md:   0%|          | 0.00/14.6k [00:00<?, ?B/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# ✅ Processor pushed successfully!
#
# 🎉 Complete! Model available at:
#    https://huggingface.co/naazimsnh02/dentalgemma-1.5-4b-it

# %% [markdown]
# **DentalGemma** — Built for the [MedGemma Impact Challenge](https://kaggle.com/competitions/med-gemma-impact-challenge) 🦷
